# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет еще раз!\
# Все критические замечания устранены, проект принят, ты молодец!
#
# Немного про суть изучаемых нами графиков. Основа это когортный анализ: Каждый конкретный день пользователи нашего приложения состоят из тех, кто только начал его использовать и тех кто уже использовал его ранее - вчера, неделю назад, месяц назад и т.д. Выводы по всей этой куче пользователей сделать нереально! Идея когортного анализа состоит в том, чтобы разделить пользователей на группы по определенным признакам, и отслеживать поведение этих групп во времени. Обычно группы пользователей (когорты) выделяют на основе недели, двух недель, месяца - когда пользователи зарегистрировались в приложении. Выделив такие группы пользователей (когорты) можно следить за ними в течение времени и измерять ключевые метрики для каждой отдельной когорты.
# Таким образом, сравнивая показатели разных когорт пользователей можно наглядно сравнивать соответствующие этим периодам времени метрики.
#
# Вот тут можно почитать подробней:
#
# https://blog.ohmystats.com/cohort-analysis/
#
# https://gopractice.ru/cohort_analysis/
#
# https://smysl.io/blog/pandas-cohorts/
#
# Желаю тебе успехов во всех будущих начинаниях! 🙂
# </div>

# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет!\
#     Ты отлично поработал, НО осталось еще одно критическое замечание: Пересмотреть общий вывод, добавить больше конкретики и дать альтернативные рекомендации отделу маркетинга.
#
# Проведи проверку и высылай проект на ревью! 🙂
# </div>

# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет!\
#     Ты верно разобрался в причинах убыточности бизнеса. Видно, что ты умеешь писать и применять функции, это здорово облегчает работу аналитика. Однако есть моменты, которые требуют твоего внимания и доработки.
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Василий, привет!
#
# Меня зовут Сергей Кулешин, и я буду делать ревью твоего проекта. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом. Моя основная цель - не указать тебе на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Уважаемый Сергей! Спасибо за ревью. За терпение и поддержку. К сожалению, из родных, близких и коллег никто в этом не разбирается и приходиться как первооткрыватель мучиться над элементарными вещами, ну если смотреть с твоих высот =) Правку делал в межкорпоративные времена и детские ёлки... и прочее. Я старался, но чем ближе новый год - тем сложнее)
#
# Поздравляю тебя с новым годом! Желаю благополучия, здоровья и всего самого наилучшего!
# Спасибо за внимание.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
#   ❌ Каждый аналитический проект должен начинаться с введения, которое содержит: название, краткое описание проекта, цели и задачи, описание исходных данных, план (декомпозицию) анализа данных и т.д. Добавь пожалуйста.
# </div>
# <div class="alert alert-danger">
# <b>Комментарий ревьюера v.2</b>
#
#   ❌ Описания проекта так и нет.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#  Добавил. Но мне самому не нравиться что добавил.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ Описание и цели проекта есть.
# </div>

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# ##### Название проекта - Анализ финансовых убытков приложения Procrastinate Pro+.
#
# Анализ приложения Procrastinate Pro+. Причины денежных убытков за последние несколько месяцев.
#
# Задача — разобраться в причинах убытков и помочь компании выйти в плюс.

# %% [markdown]
# ##### Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
#
# лог сервера с данными об их посещениях,
#
# выгрузка их покупок за этот период,
#
# рекламные расходы.

# %% [markdown]
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Ссылки на скачивание файлов лучше убрать. По правилам Яндекса проекты нельзя выкладывать с прямыми ссылками к данным.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Ай ай ай!) Забыл!) Торопился! Извиняюсь.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Отлично! Проверяю дальше. 🙂
# </div>

# %%
# подключаем модули
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# загрузим csv файлы

try: # яндексовский путь
    visit = pd.read_csv('/datasets/visits_info_short.csv', sep=',')
    order = pd.read_csv('/datasets/orders_info_short.csv', sep=',')
    cost = pd.read_csv('/datasets/costs_info_short.csv', sep=',') 
except: # мой путь
    visit = pd.read_csv('C:\jubyterbase/visits_info_short.csv', sep=',')
    order = pd.read_csv('C:\jubyterbase/orders_info_short.csv', sep=',')
    cost = pd.read_csv('C:\jubyterbase/costs_info_short.csv', sep=',')

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Кажется, работа над проектом велась локально и пути к файлам не были изменены на общедоступные. Стоит переписать код таким образом, что бы он запускался и в jupiter hub, и локально без внесения дополнительных правок. Этого можно добиться многими способами. Например, использовать конструкцию try-except для путей файлов: try - пути на локальном компьютере, except - пути на сервере.
# ```python
# try: # яндексовский путь
#     df = pd.read_csv('/folder_1/data.csv', sep=',')
# except: # мой путь
#     df = pd.read_csv('/folder_2/data.csv', sep=',')
# ```
# Или применить библиотеку os:
# ```python
# import os
#
# pth1 = '/folder_1/data.csv' # яндексовский путь
# pth2 = '/folder_2/data.csv' # мой путь
#
# if os.path.exists(pth1):
#     query_1 = pd.read_csv(pth1)
# elif os.path.exists(pth2):
#     query_1 = pd.read_csv(pth2)
# else:
#     print('Something is wrong)
# ```
# </div>

# %% [markdown]
# #####  1.1 Изучим visits (визиты)

# %% [markdown]
# Структура visits_info_short.csv:
#
# User Id — уникальный идентификатор пользователя,
#
# Region — страна пользователя,
#
# Device — тип устройства пользователя,
#
# Channel — идентификатор источника перехода,
#
# Session Start — дата и время начала сессии,
#
# Session End — дата и время окончания сессии.

# %%
# ознакомимся с датасетом
visit.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Не выводи на показ весь датафрейм, при больших объемах можно подвесить ноутбук. Используй head(), tail() или sample().
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Поправил.
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ 👌
# </div>

# %%
# посмотрим информацию
visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
# проверка на пропуски
display(visit.isna().sum())
# Out:
# User Id          0
# Region           0
# Device           0
# Channel          0
# Session Start    0
# Session End      0
# dtype: int64

# %%
# переименование названия столбцов, устранение пробелов
visit.columns = visit.columns.str.lower().str.replace(' ', '_')

# %%
# visit.columns = ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Когда колонок много, а переименовываем не все лучше использовать метод `rename()` - чтобы избежать в реальных проектах проблемы, когда последовательность в колонках может поменяться.
#
# Или использовать что-то типа такого:
# ```python
# visits.columns = visits.columns.str.lower().str.replace(' ', '_')
# ```
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# То есть команда заменяющая пробелы на нижнее подчёркивания. Супер!!!
#
# </div>

# %%
# посмотрим датасет
visit.head()
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
# преобразуем данные о времени
visit['session_start'] = pd.to_datetime(visit['session_start'])

# %%
# преобразуем данные о времени
visit['session_end'] = pd.to_datetime(visit['session_end'])

# %%
# проверка на дубликаты
visit.duplicated().sum()
# Out:
# 0

# %%
# просмотр информации о датасете после преобразований
visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Сделал head() и проверил на дубликаты
#
# </div>

# %% [markdown]
# ##### 1.2 Изучим orders (заказы)

# %% [markdown]
# Структура orders_info_short.csv:
#
# User Id — уникальный идентификатор пользователя,
#
# Event Dt — дата и время покупки,
#
# Revenue — сумма заказа.

# %%
# ознакомление с информацией в датасете
order.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Сделал head()
#
# </div>

# %%
# ознакомление с информацией в датасете
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
# проверка на пропуски
display(order.isna().sum())
# Out:
# User Id     0
# Event Dt    0
# Revenue     0
# dtype: int64

# %%
# преобразуем заголовки к нижнему регистру и убираем пробелы
order.columns = order.columns.str.lower().str.replace(' ', '_')

# %%
# order.columns = ['user_id', 'event_dt', 'revenue'] # допишем "нижнее подчёркивание между словами

# %%
# преобразуем данные о времени
order['event_dt'] = pd.to_datetime(order['event_dt'])

# %%
# проверка датасета. 
order.head()
# Out:
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99

# %%
# проверка на дубликаты
order.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Сделал head() и проверил на дубликаты
#
# </div>

# %%
# просмотр информации о датасете после преобразований
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %% [markdown]
# #####  1.3 Изучим costs (расходы)

# %% [markdown]
# Структура costs_info_short.csv:
#
# dt — дата проведения рекламной кампании,
#
# Channel — идентификатор рекламного источника,
#
# costs — расходы на эту кампанию.

# %%
# ознакомимся с датасетом
cost.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Сделал head()
#
# </div>

# %%
# ознакомимся с датасетом
cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
# приведём название стобцов к нижнему регистру
cost.columns = map(str.lower, cost.columns)

# %%
# проверка на пропуски
display(order.isna().sum())
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %%
# преобразование столбца 'dt' в вид даты
cost['dt'] = pd.to_datetime(cost['dt'])

# %%
# проверяем
cost.head()
# Out:
#           dt   channel  costs
# 0 2019-05-01  FaceBoom  113.3
# 1 2019-05-02  FaceBoom   78.1
# 2 2019-05-03  FaceBoom   85.8
# 3 2019-05-04  FaceBoom  136.4
# 4 2019-05-05  FaceBoom  122.1

# %%
# проверка на дубликаты
cost.duplicated().sum()
# Out:
# 0

# %%
# ознакомимся с датасетом после преобразований
cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   datetime64[ns]
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Сделал head() и проверил на дубликаты
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера v.2</b>
#
#   ❌ Данные подготовлены к анализу, но не проверены на дубликаты! Если таковые имеются, они могут сильно исказить наши результаты исследования.
#
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ В конце первого шага можно написать краткий вывод: что обнаружили и как исправили.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ Дубликатов нет.
# </div>

# %% [markdown]
# ### 2. Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# #####  2.1.1 Функция для создания профилей пользователей get_profiles()

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = pd.to_datetime(profiles['dt'], format="%Y-%m-%d")
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())


    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    # результаты сохраним в столбец acquisition_cost (CAC)
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# создание датасета с применением фунции get_profiles
profiles = get_profiles(visit, order, cost)

# %%
# просмотр датасета
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Снова вывод датафрейма целиком.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#    А почему обязательно применять команду head() ? Или вывод таблицы полностью считается плохим тоном?
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ Таблица вся загружается в память, Если будет несколько миллионов записей мы просто повесим ноутбук.
# </div>

# %% [markdown]
# #####  2.1.2 Функция для подсчёта Retention Rate -  get_retention()

# %%
# задаём момент анализа из задания. 01.11.2019г
observation_date = datetime(2019, 11, 1).date()  
# горизонт анализа 
horizon_days = 14

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #####  2.1.3 Функция для подсчёта конверсии - get_conversion()

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #####  2.1.4 Функция для подсчёта LTV - get_ltv()

# %%
def get_ltv(
    profiles,  # Шаг 1. Получить профили и данные о покупках
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # Шаг 2. Добавить данные о покупках в профили

    result_raw = result_raw.merge(
        # добавляем в профили время совершения покупок и выручку
        purchases[['user_id', 'event_dt', 'revenue']],
        on='user_id',
        how='left',
    )

    # Шаг 3. Рассчитать лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):

        # Шаг 3. Построить таблицу выручки
        # строим «треугольную» таблицу
        result = df.pivot_table(
            index=dims,
            columns='lifetime',
            values='revenue',  # в ячейках — выручка за каждый лайфтайм
            aggfunc='sum',
        )

        # Шаг 4. Посчитать сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)

        # Шаг 5. Вычислить размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )

        # Шаг 6. Объединить размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)

        # Шаг 7. Посчитать LTV
        # делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        # сохраняем в датафрейм данные пользователей и значения CAC, 
        # добавив параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### 2.2 Задаём функции для построения графиков:

# %% [markdown]
# filter_data() — для сглаживания данных,
#
# plot_retention() — для построения графика Retention Rate,
#
# plot_conversion() — для построения графика конверсии,
#
# plot_ltv_roi — для визуализации LTV и ROI.

# %% [markdown]
# ##### 2.2.1 Функция для сглаживания данных

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ##### 2.2.2 Функция для построения графика Retention Rate

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержания первого дня
    retention = retention.drop(columns=['cohort_size', 0])

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке — кривые удержания неплатящих
    ax2 = plt.subplot(2, 2, 2)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    plt.show()

# %% [markdown]
# ##### 2.2.3 Функция для построения графика конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### 2.2.4 Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Отличные функции!
# </div>

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# ## 3.1 Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.

# %%
# profiles = get_profiles(visit, order, cost)

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Зачем мы второй раз вызываем get_profiles и снова создаем профили?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Не знаю) Запутался.
#
# </div>

# %%
# profiles.head() # смотрим что получилось
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Старайся не выводить датафрейм через print, так визуально тяжело воспринимать. Используй или просто profiles.head(5) или вывод через display().
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Поправил. Как писал ранее - занимаюсь дырным тоном)
#
# </div>

# %%
# просмотр максимальной и минимальной даты
profiles['dt'] = profiles['first_ts'].dt.date
profiles['dt'] = pd.to_datetime(profiles['dt'], format="%Y-%m-%d")
profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
min_analysis_date = profiles['dt'].min()
observation_date = profiles['dt'].max() 
print(min_analysis_date)
print()
print(observation_date)
# Out:
# 2019-05-01 00:00:00
#
# 2019-10-27 00:00:00

# %% [markdown]
# ###### Вывод:
# Минимальная дата привлечения пользователей - 2019-05-01<br>
# Минимальная дата привлечения пользователей - 2019-10-27

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Замечательно, у нас есть даты и они совпадают с заданием!
# </div>

# %% [markdown]
# ## 3.2 Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
# профили
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Датафрейм целиком.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Поправил! Спасибо! =)
# </div>

# %%
# просмотр платёжеспособных пользователей
region_payer_share = pd.DataFrame()
region_payer_share['users_count1'] = profiles.groupby('region')['user_id'].count()
region_payer_share['payer_users_cnt'] = profiles.query('payer == True').groupby('region')['user_id'].count()
region_payer_share['share'] = 100*(region_payer_share['payer_users_cnt'] / region_payer_share['users_count1'])
region_payer_share.sort_values(by='users_count1', ascending=False)
# Out:
#                users_count1  payer_users_cnt     share
# region
# United States        100002             6902  6.901862
# UK                    17575              700  3.982930
# France                17450              663  3.799427
# Germany               14981              616  4.111875

# %% [markdown]
# ###### Вывод:
# Больше всего платёжеспособных пользователей находится США;<br>
# Меньше всего платёжеспособных пользователей в Германии.

# %% [markdown]
# ## 3.3. Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства

# %%
devices_payer = pd.DataFrame()
devices_payer['device_count'] = profiles.groupby('device')['user_id'].count()
devices_payer['payer_device_users_count'] = profiles.query('payer == True').groupby('device')['user_id'].count()
devices_payer['share1'] = 100*(devices_payer['payer_device_users_count'] / devices_payer['device_count'])

# %%
devices_payer
# Out:
#          device_count  payer_device_users_count    share1
# device
# Android         35032                      2050  5.851793
# Mac             30042                      1912  6.364423
# PC              30455                      1537  5.046790
# iPhone          54479                      3382  6.207897

# %% [markdown]
# ###### Вывод:
# Больше всего платёжеспособных пользователей заходят с устройств: Mac и iPhone;<br>
# Меньше всего платёжеспособных пользователей заходят с устройств: Android и PC.

# %% [markdown]
# ## 3.4. Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
visit.head()
# Out:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           session_end
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# 4 2019-05-01 03:57:40

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Поправил.
#
# </div>

# %%
channel_payer = pd.DataFrame()
channel_payer['channel_count'] = profiles.groupby('channel')['user_id'].count()
channel_payer['payer_channel_users_count'] = profiles.query('payer == True').groupby('channel')['user_id'].count()
channel_payer['share2'] = 100*(channel_payer['payer_channel_users_count'] / channel_payer['channel_count'])
channel_payer.sort_values(by='share2', ascending=False)
# Out:
#                     channel_count  payer_channel_users_count     share2
# channel
# FaceBoom                    29144                       3557  12.204914
# AdNonSense                   3880                        440  11.340206
# lambdaMediaAds               2149                        225  10.469986
# TipTop                      19561                       1878   9.600736
# RocketSuperAds               4448                        352   7.913669
# WahooNetBanner               8553                        453   5.296387
# YRabbit                      4312                        165   3.826531
# MediaTornado                 4364                        156   3.574702
# LeapBob                      8553                        262   3.063253
# OppleCreativeMedia           8605                        233   2.707728
# organic                     56439                       1160   2.055316

# %% [markdown]
# ###### Вывод:
# Больше всего платёжеспособных пользователей пришло с FaceBoom;<br>
# Меньше всего платёжеспособных пользователей пришло с OppleCreativeMedia;<br>
# Так же стоит отдельно отметить "organic". С данного ресурса пришло 56439 пользователей. Да. Не такие они уж и платёжоспособные, но всё же его стоит отметить и взять на заетку.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ С платящими определились!
# </div>

# %% [markdown]
# ### 4. Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# ##### 4.1 Посчитайте общую сумму расходов на маркетинг.

# %%
cost.head()
# Out:
#           dt   channel  costs
# 0 2019-05-01  FaceBoom  113.3
# 1 2019-05-02  FaceBoom   78.1
# 2 2019-05-03  FaceBoom   85.8
# 3 2019-05-04  FaceBoom  136.4
# 4 2019-05-05  FaceBoom  122.1

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Поправил. head()
#
# </div>

# %%
# общая сумма расходнов на маркетинг их датафрейма cost
cost_all_sum = cost['costs'].sum()
cost_all_sum

# %% [markdown]
# ###### Вывод:
# Общая сумма на маркетинг равна 105497.3

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Общие затраты посчитали.
# </div>

# %% [markdown]
# ##### 4.2 Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.

# %%
cost_all_sum_category = pd.DataFrame() # вызываем конструктор DataFrame
cost_all_sum_category['costs'] = cost.groupby('channel')['costs'].sum() # создаём столбец costs и группируем costs по каналам
cost_all_sum_category.sort_values(by='costs', ascending=False) # сортируем по убыванию
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# ###### Вывод:
# Больше всего траты на следующие источники - TipTop, FaceBoom;<br>
# Меньше всего траты на следующие источники - MediaTornado, YRabbit

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2 </b>
#
#   ✔️  На популярные каналы тратится больше.
#
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Стоит вывести еще процент затрат каждого канала от общей суммы, так будет понятней общая картина.
# </div>

# %% [markdown]
# ##### 4.3 Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.

# %%
expenses_in_time = cost.pivot_table(
        index='dt', columns='channel', values='costs', aggfunc='sum'
    )

# %%
expenses_in_time_week = cost

# %%
expenses_in_time_week['week'] = expenses_in_time_week['dt'].dt.isocalendar().week

# %%
expenses_in_time_week = cost.pivot_table(
        index='week', columns='channel', values='costs', aggfunc='sum'
    )

# %%
expenses_in_time_week
# Out:
# channel  AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# week
# 18           211.05     535.7    16.80         38.64               24.00
# 19           273.00     750.2    31.71         61.68               34.50
# 20           265.65     755.7    26.67         59.04               27.50
# 21           266.70     722.7    26.67         50.16               34.25
# 22           202.65    1208.9    65.52         36.96               81.75
# 23           102.90    1081.3    66.99         27.60               79.50
# 24            96.60    1042.8    52.29         29.76               71.50
# 25           141.75    1280.4    68.46         32.16               79.75
# 26           148.05    1647.8    99.75         40.56              107.00
# 27           130.20    1536.7    87.36         43.44              102.50
# 28           106.05    1124.2    62.58         28.80               81.00
# 29            97.65     975.7    61.11         26.40               68.00
# ...

# %%
expenses_in_time_week.plot(                                             
           figsize=(10, 6),
           grid=True,)

plt.title('График изменения затрат по неделям')
plt.xlabel('Дата')
plt.ylabel('Затраты')
plt.show()

# %%
cost = cost.drop('week', axis=1)

# %%
expenses_in_time_month = cost

# %%
expenses_in_time_month['month'] = expenses_in_time_month['dt'].dt.month

# %%
expenses_in_time_month = cost.pivot_table(
        index='month', columns='channel', values='costs', aggfunc='sum'
    )

# %%
expenses_in_time_month
# Out:
# channel  AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# month
# 5           1169.70    3524.4   140.28        238.56              169.75
# 6            538.65    5501.1   314.58        138.00              370.00
# 7            504.00    5294.3   313.53        138.48              366.50
# 8            579.60    6274.4   369.81        154.56              439.25
# 9            581.70    6114.9   343.98        144.72              427.75
# 10           537.60    5736.5   315.42        140.16              378.00
#
# channel  RocketSuperAds   TipTop  WahooNetBanner  YRabbit  lambdaMediaAds
# month
# 5               577.980   2981.0           418.8   299.70           458.4
# 6               325.715   6675.6           921.0   106.20           199.2
# 7               252.070   8410.2           851.4    97.38           219.2
# 8               253.110  11202.0          1040.4   124.74           220.0
# ...

# %%
expenses_in_time_month.plot(                                             
           figsize=(10, 6),
           grid=True,)

plt.title('График изменения затрат по неделям')
plt.xlabel('Дата')
plt.ylabel('Затраты')
plt.show()

# %%
plt.figure(figsize=(15,7))

ax1 = plt.subplot(1, 2, 1)
expenses_in_time_week.plot(grid=True, ax=ax1)
plt.legend()
plt.xlabel('Месяцы')
plt.title('Динамика расходов по месяцам')

ax2 = plt.subplot(1, 2, 2)
expenses_in_time_month.plot(grid=True, ax=ax2)
plt.legend()
plt.xlabel('Недели')
plt.title('Динамика расходов по неделям')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Вывод:
# Как и было написано ранее - больше всего затрат приходится на <b>TipTop</b> и <b>FaceBoom</b>. Хорошо видны пики привлечения и спады. <br>
#
# Можно отметить, что по остальным ресурсам затраты примерно одинаковы, однако стоит отметить <b>AdNonSense</b> (в мае было больше затрат, но в конце месяца затраты снизились к среднему значению большенства источников). Так же вижно, что на графике выделяется источкик <b>RockerSuperAds</b>.

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ❌ В задании просят: Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Т.е. получается два графика с разбивкой по неделям и месяцам, которые лучше разместить рядом, используя, например subplot()
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Вот!) 2 рядом получилось) что-то пришлось повозиться.
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ Отлично! Видим динамику расходов. TipTop и FaceBoom заметно выделяются.
# </div>

# %% [markdown]
# ##### 4.4 Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей

# %%
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Поправил. head()
#
# </div>

# %%
middle_cac = pd.DataFrame()
middle_cac['channale'] = profiles.groupby('channel')['acquisition_cost'].mean()
middle_cac.sort_values(by='channale', ascending=False) # сортируем по убыванию
# Out:
#                     channale
# channel
# TipTop              2.799003
# FaceBoom            1.113286
# AdNonSense          1.008054
# lambdaMediaAds      0.724802
# WahooNetBanner      0.602245
# RocketSuperAds      0.412095
# OppleCreativeMedia  0.250000
# YRabbit             0.218975
# MediaTornado        0.218717
# LeapBob             0.210172
# organic             0.000000

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ И обходятся популярные каналы дороже.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Не самый удачный тип графика, лучше заменить на столбчатый или вообще убрать.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Убрал.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Тут мы что считаем?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Убрал.
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ 👌
# </div>

# %% [markdown]
# ###### Вывод:
# Самая высокая цена привлечения одного пользователя приходится на <b>TipTop</b>;
# Самая низкая цена привлечения одного пользователя приходится на <b>LeapBob</b>;
# Так же отметим категорию <b>organic</b>. На эту категорию нет затрат вообще. Они сами пришли)

# %% [markdown]
# ### 5. Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# ##### 5.1 Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# из столбца 'channel' уберём 'organic'
profiles = profiles.query('channel != "organic"')

# %%
# сделаем копию 1
profiles1 = profiles.query('channel != "organic"').copy()

# %%
# сделаем копию 2
profiles2 = profiles.query('channel != "organic"').copy()

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# ###### Вывод:
#
# LTV - примерно на одном уровне<br>
# САС - постоянно ростёт<br>
# ROI - почти дошёл до уровня окупаемости

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ❌ Тут есть один недочет, который искажает общие данные: из расчетов нам следует исключить пользователей с органическим трафиком, поскольку мы за них ничего не платим. Всю оценку окупаемости рекламы для привлечения пользователей, рассчитываем по пользователям, пришедшим с платныx рекламныx каналов.
#
# Пересчитай все, пожалуйста! Посмотрим, насколько сильно изменятся графики. И подкорректируй выводы.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# После удаления "органического трафика" окупаемость снизилась (ROI)
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ Да, "бесплатные" пользователи сильно искажают показатели. Поэтому их надо обязательно убирать.
# </div>

# %% [markdown]
# ##### 5.2 Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.

# %%
dimensions = ['device']
# смотрим конверсию с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
dimensions = ['region']
# смотрим конверсию с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
dimensions = ['channel']
# смотрим конверсию с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# ###### Вывод:
#
# Конверсия по устройствам, странам и каналам привлечения имеет тенденцию к росту;
#
# Конверсия по устройствам: В лидерах Mac и iPhone. PC меньше всего конверсии.
#
# Конверсия по странам: Лидел - США. Остальные страны примерно равны по конверсии, но в целом примерно одинаковая конверсия.
#
# Конверсия по источникам: FaceBoom лидер.
#
#
#
# Динамика - отражена на графиках =)

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Выводы лучше разнести под соотвествующие графики.
# </div>

# %%
# смотрим удержание с разбивкой по устройствам
dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
# смотрим удержание с разбивкой по региону
dimensions = ['region']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
# смотрим удержание с разбивкой по каналам
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# ###### Вывод:
#
# В целом вывод для платежеспособных и не платежеспособных польхователей одинаков. За рассматриваемый период они значительно уменьшаются по всем категориям (устройство, страна, и канал привлечения). <br>
#
# Однако платежеспособные пользователи удерживаются дольше по всем категориям (устройство, страна, и канал привлечения). Вероятно для них есть условия заинтересованности.

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ❌ У нас тут минимум две проблемы по странам и по каналам, стоит назвать проблемные места.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Удержание платёжоспособных пользователей в странах Европы намного лучше, чем в США. В США плавная нисходящая кривая. В Европе периодический всплекс интереса.
#
# Удержание платёжоспособных пользователей по каналам - по источникам FaceBoom и AdNonSense gлавная нисходящая кривая. Интерес только падает. А по остальным так же интерес падает, но видны колебания. Соответвенно у пользователей данных источников возникает интерес удердания.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ Обнаружили проблему в США. И видим причину не окупаемости каналов FaceBoom и AdNonSense.
# </div>

# %% [markdown]
# ##### 5.3 Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по источникам привлечени
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# ###### Вывод:
#
# LTV - начиная с мая по середину июня был прирост по всем устройствам, но начиная со второй половины июня ситуация стабилизировалась.
#
# CAC - цена привлечения по всем устройствам ростёт. С мая по середину июня резкий рост. Вероятно агрессивная реклама. Со второй половины  июня рост стоимости привлечения плавно стабильно увеличивается;
#
# ROI - привлечение пользователей Android и PC окупилась! А вот Mac и iPhone нет.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ⚠️ Тут теперь окупается только PC.
# </div>

# %% [markdown]
# ##### 5.4 Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по источникам привлечения
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# ###### Вывод:
#
# LTV - у США самая высокая
#
# CAC - США в лидерах;
#
# ROI - в США не окупается. Окупается реклама только во Франци, Германии и Великобритании.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Согласен, можно еще изучить рекламу в США отдельно.
# </div>

# %%
profiles = profiles.query('region != "France" & region !="UK" & region !="Germany"')

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Изучаем США отдельно. Соответственно убираем все ненужные регионы.
#
# Что мы видем:
#
# LTV - рост по восходящей
#
# LTV динамика нам говорит, что существует всплески и спады привлечённых пользователей. Соответственно на диаграмме видно, что в середине июня, июля и августа и начала сентября рост привлечённых пользователей из США. Во второй половине сентября происходит относительная стабилизация.
#
# САС - Диаграмма стоимости привлечения - стоимость привлечения пользователей из США постоянно ростёт. Во второй половине сентября видна стабилизация стоимости привлечения, однако она остаётся на пиковых значениях.
#
# ROI - пользователи из США самые "дорогие", однако они не окупаются. Что видно на диаграмме.
#
# Динамика ROI - видно, что динамика резко отрицательна. То есть почти весь график за черной окупаемости.
#
# Вывод:
# При значительных денежных "вливаниях" пользователям из США не интересно приложение Procrastinate Pro+.
#
#
# </div>

# %% [markdown]
# ##### 5.5 Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# ###### Вывод:
# LTV - существенно не различается<br>
# САС - отличный рост у TipTop<br>
# ROI - привлечение пользователи из каналов: TipTop, FaceBoom, AdNonSense не окупается<br>

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Определили проблемные каналы!
# </div>

# %% [markdown]
# ##### 5.5.1  Дополнительно. Проанализируем окупаемость рекламы с разбивкой по перспективным (окупаемым) рекламным каналам MediaTornado, RocketSuperAds и YRabbit в США. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Добавил.
#
#
# </div>

# %%
profiles1 = profiles1.query('region != "France" & region !="UK" & region !="Germany" & channel != "FaceBoom" & channel != "TipTop"')

# отфильтруем profiles1

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles1, order, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# ###### Вывод:
# LTV - RocketSuperAds гораздо популярнее двух стальных каналов<br>
# Динамика LTV - пользователи с RocketSuperAds более ценные, чем с других ресурсов, хотя в целом все окупаемые пользователи важны =)<br>
# САС - цена привлечения пользователей RocketSuperAds только падает.<br>
# ROI - рассматреваемые каналы окупаются в США, что не может не радовать<br>
# Динамика ROI - все каналы в целом успешно окумаются, есть конечто незначительный вынос за пределы окупаемости, но это в целом не критично
#
# ###### Общий вывод:
# В США стоит обратить внимание на пользователей канала RocketSuperAds.

# %% [markdown]
# ##### 5.5.2  Дополнительно. Проанализируем окупаемость рекламы с разбивкой по перспективным (окупаемым) рекламным каналам LeapBob, OppleCreativeMedia, WahooNetBanner и lambdaMediaAds в странах Европы. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Добавил.
#
#
# </div>

# %%
profiles2 = profiles2.query('region != "United States" & channel != "AdNonSense"')

# отфильтруем profiles2

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles2, order, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# ###### Вывод:
# LTV - lambdaMediaAds гораздо популярнее четырёх стальных каналов в Европе<br>
# Динамика LTV - пользователи с lambdaMediaAds и LeapBob более ценные, чем с других ресурсов, хотя в целом все окупаемые пользователи важны =)<br>
# САС - цена привлечения пользователей lambdaMediaAds и LeapBob стабильная и выше чем у усоальных каналов. <br>
# ROI - рассматреваемые каналы окупаются в Европе, что не может не радовать!!!<br>
# Динамика ROI - На каналах lambdaMediaAds и LeapBob динамика гораздо выше остальных каналов, хотя виждно, что наименьшая динамика у канала WahooNetBanner<br>
#
# ###### Общий вывод:
# В Европе стоит обратить внимание на пользователей каналов lambdaMediaAds и LeapBob.

# %% [markdown]
# ##### 5.6 Ответьте на такие вопросы:

# %% [markdown]
# ###### 5.6.1 Окупается ли реклама, направленная на привлечение пользователей в целом?

# %% [markdown]
# Реклама в целом окупается, но существую источники, страны и устройства, на которые нужно обратить внимание. На них не окупается реклама.

# %% [markdown]
# ###### 5.6.2 Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?

# %% [markdown]
# Негативное влияние на окупаемость рекламы оказывают:<br>
# Устройства: Mac и iPhone<br>
# Страны: США<br>
# Каналы: TipTop, FaceeBoom, AnNonSense<br>

# %% [markdown]
# ###### 5.6.3 Чем могут быть вызваны проблемы окупаемости?

# %% [markdown]
# Высокая стоимость привлечения аудитории

# %% [markdown]
# ### 6. Напишите выводы

# %% [markdown]
# ###### 6.1 Выделите причины неэффективности привлечения пользователей.

# %% [markdown]
# На мой взгляд причиной неэффективности является слишком большое уделение внимания крупным источникам, таким как TipTop, FaceBoom. Слишком болье удиление внимания пользователям из США. Стоимост привлечения большая, а эффективность низкая.

# %% [markdown]
# ###### 6.2 Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# Необходимо уделить больше внимания пользователям PC и Androind, т.к. данные платформы больше распространены и более окупаемы. Уделить больше внимания другим рассматриваемым странам - Франция, Германия и Великобритания. Уделить больше внимания другим рассматриваемым каналам (не TipTop, FaceeBoom, AnNonSense).

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ❌ В этом проекте очень важно дать интерпретацию графикам и написать развернутые выводы.
# Нам надо найти и указать причины плохой окупаемости рекламы:
# - реклама в США - проблемы такие-то
# - канал TipTop - увеличение САС
# - канал FaceBoom, AdNonSense - проблемы с ..? (мы говорим, что они не окупаются но не называем причину)
# - рассмотреть ситуацию с устройствами\
# и т.д.
#
# А так-же еще написать рекомендации по альтернативным регионам и каналам: на какой окупающийся источник следует обратить внимание, чтобы оптимизировать затраты на рекламу в США? Какие перспективные каналы посоветовать по Европе  и т.д.  маркетологи оценят! 🙂
#
# </div>
#
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ❌ В выводе так и не видим причин не окупаемости США и какие проблемы у каналов TipTop, FaceBoom и AdNonSense?
#
# А в рекомендации стоит добавить несколько перспективных каналов, в идеале с привязкой к регионам (США и Европа).
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.4</b>
#
#   ✔️ Вывод преобразился, теперь видно в чем проблема и даны рекомендации для ее устранений.  👍
# </div>

# %% [markdown]
# ###### 6.1 (дополнения по замечаниям) Выделите причины неэффективности привлечения пользователей.

# %% [markdown]
# При значительных денежных "вливаниях" пользователям из США не интересно приложение Procrastinate Pro+. Проблемы по FaceBoom и AdNonSense - платформы очень популярные, но привлечённым платёжеспособным пользователям не интересно приложение Procrastinate Pro+. Вероятно это не наша целивая аудитория. TipTop - аудитория очень затратная для привлечения.

# %% [markdown]
# ###### 6.2 (дополнения по замечаниям) Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# К перспективным каналам в США отнесём - RockerSuperAds, MediaTornado и YRebbit. Согласно ROI они окупаются. Значит платежеспособная аудитория этих каналов заинтересовалась приложением Procrastinate Pro+.
#
# В Европе к перспективным каналам отнесём lambdaMediaAds и LeapBob. Платежеспособная аудитория этих каналов больше всего заинтересована приложением Procrastinate Pro+.

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#   <b>Чек-лист доработок</b>
#
#   📃 Добавить краткое описание проекта.
#
#   📃 Сократить все выводы датафреймов до 5 строк, этого достаточно для беглого ознакомления с данными.
#
#   📃 Проверить данные на дубликаты.
#
#   📃 Визуализировать динамику изменения расходов на маркетинг во времени (по неделям и месяцам) по каждому источнику.
#
#   📃 Убрать канал "organic" из анализа причин неудовлетворительной окупаемости рекламных затрат.
#
#   📃 Проверить выводы по графикам в шаге анализа причин неудовлетворительной окупаемости рекламных затрат.
#
#   📃 Написать более развернутый общий вывод, добавить альтернативные рекомендации отделу маркетинга.
#
#
# Жду твой проект на повторное ревью. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится.
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок v.2</b>
#
#   📃 Пересмотреть общий вывод, добавить больше конкретики и дать альтернативные рекомендации отделу маркетинга.
#
# Исправляй и присылай проект на ревью.
# </div>
