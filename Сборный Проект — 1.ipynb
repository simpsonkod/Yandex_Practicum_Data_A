# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b><br><br>
# <b>Версия от: 27.11.2022г.</b>
#
# Уважаемый ревьюер. Знаю, что получилось совем не идеально и уже не вовремя. Видимо когда Вы это читаете - наступил уже дэдлайн.<br>
# Из-за постоянной нехватки времени по лично-бытовым причинам (молодой папа, работа 5/2) пришлось изучать на "бегу". Что-то "гуглить" и что-то подсматривать.<br>
# Я в общем-целом понимаю подход и концепцию исследования CSV файла, но к сожалению нет времени из-за постоянных гонок на ПРАКТИКУМЕ. 2 часов в день для меня явно мало. Мне нужно спокойно самому без спешки попрактиковаться по вариантам вывода информации, подсчётам, построению графиков и тд. Но это я смогу сделать вне ПРАКТИКУМА. Когда это всё закончится.<br>
#
# Прошу не считать этот пост "нытьём" или чем-то подобным, просто хотел донести до Вас искренне и честно состояние моих дел.<br>
#
# Я хочу продолжить дальнейшее обучение, мне очень нравится, но как водиться чего-то не хватает. Времени получше разобраться. <br>
#
# Спасибо за внимание. Не хотел напрягать своим обращением.
#
# ps.
# Вывод налепил уже в полусонном состоянии.
#
# <b>Версия от: 28.11.2022г.</b>
# Уважаемый Марат! Я постарался внести все изменения по твоим замечаниям. Так же прочитал все "жёлтые квадраты". Огромное спасибо за инфу. Я обязательно попробую разные варианты, но уже за чертой дэдлайна и т.д., Честно говоря, хотелось бы и в этом изменении (этой версии проекта) что-то применить, но жёсткие рамки не дают попробовать. Мой дэдлайн продлили до вторника))) Сижу вот уже поздно вечером за ноутбуком и "быстрее-быстрее" пытаюсь исправить, доделать, переделать. Первый спринт очень даже помог поставить себя на "рельсы" да и ознакомиться с принципами обучения. Да и навёл на определённые изменения в личном "тайм менеджменте". В общем отправляю на проверку.
#
# Ps - я провёл работу над ошибками) Не везде, но много где. Грамматика наше всё! =) Ошибки в юпитере не подчёркиваются)))
#
# Pss - а ещё я понял, что надо подтянуть и на что обратить внимание.
#
# Psss - честно говоря хочу много что сказать, поделиться эмоциями и прочее, но не хочу тебя больше напрягать моей писаниной =)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Привет Василий! Прочитал )
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет Василий! Твой комментарий звучит так, что я уже заранее достаю красный фломастер )
#
#
# Меня зовут Марат, и я буду твоим ревьюером. Спешу сообщить что все ключевые этапы в работе выполнены,  с задачей тебе удалось справиться. По поводу обращения - в IT сфере принято общаться на «ты» :) Но, если привычней на «вы», дай знать. Как ревьюера моя задача помочь тебе в развитии, дав хорошие советы. Я внимательно посмотрю твой код, ознакомлюсь с твоими выводами и оставлю комментарии. Где то могу предложить небольшие исправление в коде, но ненавязчиво. Где потребуются уточнения, я оставлю много наводящих вопросов. Они помогут тебя с поиском верного решения.
#
# Все мои комментарии размечены по цветам, для лучшего восприятия.
#
# <div class="alert alert-success">Зеленым цветом и словом «Успех» отмечены особо удачные и элегантные решения, которыми ты можешь гордиться. </div>
#
# <div class="alert alert-warning">Желтым и значком словом «Совет», помечены решения у которых есть альтернативные решения, более оптимальные. Ты можешь найти их сразу и доработать проект, или отложить это на потом, для будущих проектах. Проект будет принят и без их доработки. </div>
#
# <div class="alert alert-danger"> Красным цветом и значком словом «Ошибка» помечу твои решения, на которые стоит обратить внимание прежде всего. После их доработки проект будет принят. </div>
#
# Залог успеха - работа сообща, взаимное уважение и работа в диалоге. Поэтому, помечай свои ответные комментарии на мои реплики заметным цветом или курсивом, так мне будет легче их отслеживать. Пожалуйста, не изменяй и не удаляй мои комментарии. Все это поможет выполнить повторную проверку быстрей.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
#
# Вступление в работу очень важно, так человек, который смотрит твой проект (и на работе в том числе) будет сразу введен в курс дела.
#
#
#
#
#
# </div>

# %% [markdown]
# Вступление:
#
# Из разных источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). В проекте нужно выявить определяющие успешность игры закономерности. Это позволит сделать выбрать потенциально популярный продукт и приоритеты для продаж и рекламы. Перед нами данные до 2016 года. Нужно отработать принцип работы с данными.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍
#
#
#
#
# </div>

# %%
# импортируем модули
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
from collections import Counter
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Собираем все импорты в верхней части, чтобы легче было ориентироваться и добавлять новые по необходимости.
#
#
# <div class="alert alert-warning">
#
# Совет:
#
#
# - кстати есть рекомендации PEP-8 при написании кода, в том числе и для импортов. Если интересно можешь почитать [тут](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html), это на будущее

# %%
# испортируем базу данных
try:
    data = pd.read_csv('C:\jubyterbase/games.csv') 
except:
    data = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Молодец что используешь конструкцию try - except (if - else), этим ты проявляешь уважение к тем кто будет работать с твоим кодом.
#
# </div>

# %% [markdown]
# <b>1. Открываем файл с данными и приступим к изучению информации</b>

# %%
# ознакомимся с базой
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
# выводим информацию обо всех колонках
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# проверка пропусков
display(data.isna().sum())
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
# посмотрим распределение числовых значений 
data.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# К нашему вниманию следующие столбцы:
#
# •	Name — название игры
#
# •	Platform — платформа
#
# •	Year_of_Release — год выпуска
#
# •	Genre — жанр игры
#
# •	NA_sales — продажи в Северной Америке (миллионы проданных копий)
#
# •	EU_sales — продажи в Европе (миллионы проданных копий)
#
# •	JP_sales — продажи в Японии (миллионы проданных копий)
#
# •	Other_sales — продажи в других странах (миллионы проданных копий)
#
# •	Critic_Score — оценка критиков (максимум 100)
#
# •	User_Score — оценка пользователей (максимум 10)
#
# •	Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %%
# посмотрим распределение значений на графиках стандартного инструмента pandas
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет 🤔:
#
#
# - Если хочешь убрать AxesSubplot:xlabel..  то ставь в конце `;` или пропиши plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
#
# info(), describe() получено первичное представление о данных.
#
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
#
#
#
# - .sample (выводит вразнобой) лучше .head (выводит первые строки), ведь если данные каким то образом упорядоченны, то шансы увидеть что то разнообразное через .sample чуть выше чем через .head (или .tail - выводит последние строки)

# %% [markdown]
# <b>2. Предобработка данных </b>

# %% [markdown]
# # 2.1 Задание: Замените названия столбцов (приведите к нижнему регистру)

# %%
# приведём название столбцов к ниждему регистру
data.columns = map(str.lower, data.columns)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Все верно, использование .lower предпочтительно в данном случаи, (ведь нас не просят переименовать а только привести к строчному виду) так мы автоматизируем работу, впереди у нас датасеты с сотнями столбцами которые нам переделывать через .rename() будет затруднительно.

# %%
# проверим что получилось
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# # 2.2 Задание: Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;

# %% [markdown]
# Преобразуем столбец year_of_release (год выпуска) из float64 в int64. Год не пишеться через запятую в числе =)

# %%
#  приведём 'year_of_release' к числовому значению
data['year_of_release'] = data['year_of_release'].astype('Int64')

# %% [markdown]
# Cтолбец 'user_score' (оценка пользователей (максимум 10)) имеет тип object

# %%
# посмотрим количество уникальных значений в 'user_score'
data['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# Изучение столбца показала следующие - в наличии имеются цифры с рейтингом игр, строчки NaN и tbd, которое не позволяет изменить тип столбца на Float64. Выясним поподробнее о tbd. Сделаем срез данных методом query

# %%
# извлечём строки содержащие "tbd" из столбца 'user_score' командой query 
data.query('user_score =="tbd"')
# Out:
#                                            name platform  year_of_release  \
# 119                               Zumba Fitness      Wii             2010
# 301              Namco Museum: 50th Anniversary      PS2             2005
# 520                             Zumba Fitness 2      Wii             2011
# 645                                uDraw Studio      Wii             2010
# 657    Frogger's Adventures: Temple of the Frog      GBA             <NA>
# ...                                         ...      ...              ...
# 16695                           Planet Monsters      GBA             2001
# 16697                          Bust-A-Move 3000       GC             2003
# 16698                          Mega Brain Boost       DS             2008
# 16704                                  Plushees       DS             2008
# 16706             Men in Black II: Alien Escape       GC             2003
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %%
# Заменим "tbd" на Nan
data.loc[data['user_score']=="tbd", 'user_score']=np.nan
# Заменим тип данных пользовательского рейтинга с object на float64
data['user_score'] = data['user_score'].astype('float64')

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Погугуглено - выяснено -  сделано.
#
# Верно что обошлось без удаления, или попыток заменить на "среднюю по больнице" итп.   tbd по сути это Nan
#
#
#
#
# <div class="alert alert-warning">
#
#
#
# Совет:
#
#
# Также нелишним всегда будет прописать объяснение непонятных значений как, например, tbd, потому что некоторые термины могут быть непонятными для твоих коллег :)
#
#
# </div>

# %%
# посмотрим что получилось
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN

# %% [markdown]
# Проверяем что получилось:

# %%
# после изменения посомтрим информацию обо всех колонках
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: Int64(1), float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# На мой взгляд изменять типы данных больше негде. Приступлю к следующиму заданию.

# %% [markdown]
# # 2.3 Задание: Обработка пропусков

# %% [markdown]
# Проверим ещё раз где у нас есть пропуски:

# %%
# проверим пропуски
display(data.isna().sum())
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %% [markdown]
# Пропуски имеются в стробцах:
# name (название игры),
#
# year_of_release(год выпуска),
#
# genre(жанр игры),
#
# critic_score(оценка критиков (максимум 100)),
#
# user_score(оценка пользователей (максимум 10)),
#
# rating(рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.)
#
# Изучим столбцы с пропусками поподробнее.

# %% [markdown]
# - name (название игры):

# %%
# командой query посмотрим незаполенные ячейки NaN
data.query('name.isnull()')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %% [markdown]
# В связи с незначительным количеством пропущенных ячеек с названием игр и невозможности узнать их - мы их удалим.

# %%
# удалим незаполненные строки втолбца 'name'
data.dropna(subset=['name'], inplace = True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Обоснование и решение удалить genre и name верное. Методы применены оптимально. Молодец
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
#
# - Если вдруг не знаешь,   удалять можно целой пачкой:
#
#     df.dropna(subset=['year_of_release', 'name', 'genre'])
#
#
#
# - Решение верное, но перед удалением стоит посмотреть на записи  может на удаленные пару строк приходится по 100 млн. продаж

# %% [markdown]
# Проверяем.

# %%
# после удаления пропусков в 'name' посмотрим что получилось
display(data.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating             6764
# dtype: int64

# %% [markdown]
# - genre(жанр игры):

# %% [markdown]
# Изучим причину пропусков

# %%
# проверим количество уникальных значений в 'year_of_release'
data['year_of_release'].unique()
# Out:
# <IntegerArray>
# [2006, 1985, 2008, 2009, 1996, 1989, 1984, 2005, 1999, 2007, 2010, 2013, 2004,
#  1990, 1988, 2002, 2001, 2011, 1998, 2015, 2012, 2014, 1992, 1997, 1993, 1994,
#  1982, 2016, 2003, 1986, 2000, <NA>, 1995, 1991, 1981, 1987, 1980, 1983]
# Length: 38, dtype: Int64

# %%
# извлечём пропущенные строки в столбце 'year_of_release' командной query
data.query('year_of_release.isnull()').head()
# Out:
#                            name platform  year_of_release     genre  na_sales  \
# 183             Madden NFL 2004      PS2             <NA>    Sports      4.26
# 377            FIFA Soccer 2004      PS2             <NA>    Sports      0.59
# 456  LEGO Batman: The Videogame      Wii             <NA>    Action      1.80
# 475  wwe Smackdown vs. Raw 2006      PS2             <NA>  Fighting      1.57
# 609              Space Invaders     2600             <NA>   Shooter      2.36
#
#      eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 183      0.26      0.01         0.71          94.0         8.5      E
# 377      2.36      0.04         0.51          84.0         6.4      E
# 456      0.97      0.00         0.29          74.0         7.9   E10+
# 475      1.02      0.00         0.41           NaN         NaN    NaN
# 609      0.14      0.00         0.03           NaN         NaN    NaN

# %% [markdown]
# В связи с отсутствием дат выхода игр мы не сможем заполнить неизвестные даты и пока оставим всё как есть

# %%
# посмотрим информацию о датасете снова
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16444 non-null  Int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: Int64(1), float64(6), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# •	Critic_Score — оценка критиков (максимум 100):

# %%
# посмотрим количество уникальных значений в столбце 'critic_score'
data['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])

# %%
# извлечём пропущенные строки в столбце 'critic_score' командной query
data.query('critic_score.isnull()').head()
# Out:
#                         name platform  year_of_release         genre  \
# 1          Super Mario Bros.      NES             1985      Platform
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 9                  Duck Hunt      NES             1984       Shooter
# 10                Nintendogs       DS             2005    Simulation
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 1      29.08      3.58      6.81         0.77           NaN         NaN    NaN
# 4      11.27      8.89     10.22         1.00           NaN         NaN    NaN
# 5      23.20      2.26      4.22         0.58           NaN         NaN    NaN
# 9      26.93      0.63      0.28         0.47           NaN         NaN    NaN
# 10      9.05     10.95      1.93         2.74           NaN         NaN    NaN

# %% [markdown]
# К сожалению не ясно почему не был проставлены оценки критиков в столбец critic_score. Ввиду большого количества незаполненной информации принимаю решение ничего не трогать.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Совет 🤔:
#
#
# Скорее всего это связано с малопопулярностью игр.  Если посмотреть на продаже игр с пропусками именно такой вывод можно сделать
# </div>

# %% [markdown]
# •	User_Score — оценка пользователей (максимум 10)

# %%
# извлечём пропущенные строки в столбце 'user_score' командной query
data.query('user_score.isnull()').head()
# Out:
#                         name platform  year_of_release         genre  \
# 1          Super Mario Bros.      NES             1985      Platform
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 9                  Duck Hunt      NES             1984       Shooter
# 10                Nintendogs       DS             2005    Simulation
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 1      29.08      3.58      6.81         0.77           NaN         NaN    NaN
# 4      11.27      8.89     10.22         1.00           NaN         NaN    NaN
# 5      23.20      2.26      4.22         0.58           NaN         NaN    NaN
# 9      26.93      0.63      0.28         0.47           NaN         NaN    NaN
# 10      9.05     10.95      1.93         2.74           NaN         NaN    NaN

# %% [markdown]
# Как и в предудыщем случае не ясно почему не проставлена оценка пользователей. Оставляем незаполненные ячейки без изменений.

# %% [markdown]
# •	Rating — рейтинг от организации ESRB

# %%
# извлечём пропущенные строки в столбце 'rating' командной query
data.query('rating.isnull()')
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# С рейтингом таже самая ситуация, что и выше с рейтигнами.

# %% [markdown]
# 2.4 Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец

# %%
# подсчёт суммарного объёма продаж 'na_sales' (надо потом попробовать цикл написал)
data['na_sales'].sum()
# Out:
# 4400.570000000001

# %%
# подсчёт суммарного объёма продаж 'eu_sales'
data['eu_sales'].sum()
# Out:
# 2424.1400000000003

# %%
# подсчёт суммарного объёма продаж 'jp_sales'
data['jp_sales'].sum()
# Out:
# 1297.34

# %%
# подсчёт суммарного объёма продаж 'other_sales'
data['other_sales'].sum()
# Out:
# 791.2400000000001

# %%
# суммируем данные
data['all_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']

# %%
# вышеизложенное, но на "пандосовском варианте" (для примера. На учебном варианте слелал первый вариант подсчёта, да)) учусь)
data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1).head()
# Out:
# 0    82.54
# 1    40.24
# 2    35.52
# 3    32.77
# 4    31.38
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
# Твой код отработал норамально, но есть более "пандовский" вариант
# ```
# df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)
# ```
# где axis = 1 означает что мы считаем по горизонтали, axis = 0 по вертикали.
#
# </div>

# %%
# посмотрим новые столбцы
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  all_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1      3.58      6.81         0.77           NaN         NaN    NaN      40.24
# 2     12.76      3.79         3.29          82.0         8.3      E      35.52
# 3     10.93      3.28         2.95          80.0         8.0      E      32.77
# 4      8.89     10.22         1.00           NaN         NaN    NaN      31.38

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
# Оставить пропуски в rating без изменений - это не ошибка. Но в дальнейшем тебе следовало обратить внимание на это при анализе игр по регионам (ведь при группировке по rating с помощью pivot_table или group_by, по nan агрегированные данные не считаются, как результат очень много информации мы потеряли). К сожалению этого сделано не было. Подумай, (можешь погуглить о рейтинге ESRB) чем могут быть вызваны пропуски и на что стоит их заменить, чтобы было информативно и не выбивалось из других значений этого столбца.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# В столбец rating входят 6764 пропуска
#
# Судя по wikipedia ( https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board ), то рейтинг ESRB начали присваивать только с 1994 года. Соответственно делаю вывод, что 361 игры вышедшие до 1994г игры выбывают - заполню эти пропуски так "no_information_about_rating".
#
# <br>
# Что касается игр с 1994 года без рейтинга ESRB, то мне удалось найти следующее:
#
# "Если вы хотите, чтобы ESRB оценил вашу игру, вы должны заплатить им за просмотр и оценку. Вам также необходимо предоставить игровые клипы и письменные обзоры геймплея и любой возможный нежелательный контент в вашей игре. ESRB просто просматривает это и выносит свое решение. Насколько мне известно, они никогда не играют в игры."
#
# Вот ссылка: https://steamcommunity.com/discussions/forum/1/458604254458291493/
#
# Видимо издатели не захотели платить за это.
#
# Так же заполним пропуски "no_information_about_rating", т.к. по данной выгрузке (games.csv) мы не знаем присвоен ли рейтинг игре или нет.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Совет 🤔:
#
#
# А ещё рейтинг ESRB - это американский рейтинг, а в Японии есть своё рейтинговое агентство. Япония страна со своим менталитетом, верят только своим. Вот и получается что игры рынка Японии имеет самое большое количество пропусков в rating
#
# </div>

# %%
# создадим датасет rating_test и выведим пропуски в 'rating'
rating_test = data.query('rating.isnull()')

# %%
# отфильтруем 'year_of_release' начиная с 1993 года
rating_test[rating_test['year_of_release'] >= 1993]
# Out:
#                                 name platform  year_of_release         genre  \
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 10                        Nintendogs       DS             2005    Simulation
# 12       Pokemon Gold/Pokemon Silver       GB             1999  Role-Playing
# 20     Pokemon Diamond/Pokemon Pearl       DS             2006  Role-Playing
# 25     Pokemon Ruby/Pokemon Sapphire      GBA             2002  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
# Заполняем все пропуски NaN сообщением 'no_information_about_rating'
data['rating'] = data['rating'].fillna('no_information_about_rating')

# %%
# проверка заполнений в столбце 'rating'
display(data.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating                0
# all_sales             0
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
#
# Что можно было сделать еще?
#
# Заняться неявными дубликатами в рейтингах и названиях игр. Данные стали бы чуть чуть чище.
#
#
# На примере рейтингов это могло выглядеть так:
#
# 1. Используем value_counts() к rating и обнаруживаем небольшое число у K-A и EC.
# 2. Гуглим и обнаруживаем что это старая версия E (можно продолжить выяснять)..
# 3. Делаем замены. Такой вариант работы с неявными дубликатами.
#
# С именами сложней, тут бы помогли регулярные выражения.
#
#
# Это тоже предобработка данных.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Совет 🤔:
#
# В конце раздела рекомендую оставлять промежуточный вывод
#
# </div>

# %% [markdown]
# # <b>3. Проведите исследовательский анализ данных</b>

# %% [markdown]
# # Задание: Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %% [markdown]
# Сделаем 2 столбца - года релиза и количество релизов

# %%
# создадим датасет release_year и сгруппируем данные по годам и названия игры. Подсчитам общее количество
release_year = data.groupby('year_of_release')['name'].count()
release_year
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %% [markdown]
# Мы увидели сколько игр выпускалось в разные годы. Судя по полученной информации, можно сделать вывод, что с 1980 по 1990 годы релизов было намного меньше. Видимо в данный период были проблемы с релизом, да и в целом с технологией производства видеоигр. Кстати не для рекламы, а для совета) Канал Pixel Devil - Russian Geek. Отличный канал про историю видеоигр =) Надеюсь мой ревьюер в теме))  https://www.youtube.com/user/PxlDevil . Данные за все периоды конечно важны. На мой взгляд это связано с развитием технологии производства видеоигр и распространение в виду развития массмедиа и интернета в мире.

# %% [markdown]
# <b>3.2</b> Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
# создадим датасет с суммарными продажами и распределением по годам
platform = data.groupby('platform')['all_sales'].sum().sort_values().reset_index()

# %%
platform
# Out:
#    platform  all_sales
# 0      PCFX       0.03
# 1        GG       0.04
# 2       3DO       0.10
# 3      TG16       0.16
# 4        WS       1.42
# 5        NG       1.44
# 6       SCD       1.86
# 7        DC      15.95
# 8       GEN      28.35
# 9       SAT      33.59
# 10      PSV      54.07
# 11     WiiU      82.19
# 12     2600      96.98
# 13     XOne     159.32
# 14       GC     198.93
# 15     SNES     200.04
# 16      N64     218.68
# 17      NES     251.05
# 18       GB     255.46
# 19       XB     257.74
# 20      3DS     259.00
# 21       PC     259.52
# 22      PSP     294.05
# 23      PS4     314.14
# 24      GBA     317.85
# 25       PS     730.86
# 26       DS     806.12
# 27      Wii     907.51
# 28      PS3     939.65
# 29     X360     971.42
# 30      PS2    1255.77

# %% [markdown]
# Выбираем платформы с наибольшим суммарным объёмом продаж

# %%
# надём суммарный объём продаж
platform_top_sales_10 = data.groupby('platform')['all_sales'].sum().sort_values(ascending=False).reset_index().head(10)
platform_top_sales_10
# Out:
#   platform  all_sales
# 0      PS2    1255.77
# 1     X360     971.42
# 2      PS3     939.65
# 3      Wii     907.51
# 4       DS     806.12
# 5       PS     730.86
# 6      GBA     317.85
# 7      PS4     314.14
# 8      PSP     294.05
# 9       PC     259.52

# %% [markdown]
# Вот такой ТОП-10 продаж консолей по всему миру получился. Самая популярная, ожидаемо, PS2 =)

# %% [markdown]
# Построем гистограмму продаж по годам:

# %%
# построем диаграмму продаж по годам
data.groupby('year_of_release')['all_sales'].sum().plot(x='release_year', y='all_sales', kind='bar', figsize=(9,5))
plt.title('Продажи по годам  ')
plt.xlabel('Год выпуска')
plt.grid(True)
plt.show();

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
# Успех:
#
#
# График построен хорошо надписи все присутствуют, figsize  подобран.  Почему это может быть важно?! Графики первое что бросается в глаза, а первое впечатление порой определяющее.
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
# - Советую использовать [seaborn](https://habr.com/ru/company/otus/blog/540526/).  Он строит красивее, с ним можно строить техничней, он много работы сделает за тебя.

# %%
# создаю датасет top_platform с указанием топ 10 платформ консолей
top_platform = platform_top_sales_10['platform']
top_platform
# Out:
# 0     PS2
# 1    X360
# 2     PS3
# 3     Wii
# 4      DS
# 5      PS
# 6     GBA
# 7     PS4
# 8     PSP
# 9      PC
# Name: platform, dtype: object

# %%
data_new_top = data.query('platform in @top_platform')
data_new_top
# Out:
#                                                    name platform  \
# 0                                            Wii Sports      Wii
# 2                                        Mario Kart Wii      Wii
# 3                                     Wii Sports Resort      Wii
# 6                                 New Super Mario Bros.       DS
# 7                                              Wii Play      Wii
# ...                                                 ...      ...
# 16708                Woody Woodpecker in Crazy Castle 5      GBA
# 16709  SCORE International Baja 1000: The Official Game      PS2
# 16710                     Samurai Warriors: Sanada Maru      PS3
# 16711                                  LMA Manager 2007     X360
# 16713                                  Spirits & Spells      GBA
#
#        year_of_release     genre  na_sales  eu_sales  jp_sales  other_sales  \
# 0                 2006    Sports     41.36     28.96      3.77         8.45
# ...

# %%
data_new_top.groupby('year_of_release')['all_sales'].sum().plot(x='year_of_release', y='all_sales', kind='bar', figsize=(10,6))
plt.title('Продажи на Топ-10 платформ по годам\n  ')
plt.xlabel('Год выпуска')
plt.grid(True)
plt.show();

# %% [markdown]
# Видны ТОП продаж по консолям. Лучшие года 2008-2009.

# %%
# создадим датасет со сгруппированными данными и суммируем "all_sales"
data_new_top_years = data_new_top.groupby(['platform', 'year_of_release']).agg({'all_sales':'sum'}).reset_index()
data_new_top_years.head()
# Out:
#   platform  year_of_release  all_sales
# 0       DS             1985       0.02
# 1       DS             2004      17.27
# 2       DS             2005     130.14
# 3       DS             2006     119.81
# 4       DS             2007     146.94

# %%
# 
data_new_top_years['platform'].value_counts()
# Out:
# PC      26
# PS2     12
# PSP     12
# X360    12
# DS      11
# PS3     11
# Wii     11
# PS      10
# GBA      8
# PS4      4
# Name: platform, dtype: int64

# %% [markdown]
# 3.3 Задача: Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.

# %% [markdown]
# Платформы живут где-то 11 лет. Возьмём эту цифру за расчётную (актуальную). Ожидаемо, что PC самая живучая платформа с видеоиграми, но в виду особенности консольного рынка - много классных эксклюзивов выходит на определённой платформе, а потом уже на остальных (через 1 год или более).

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
#
# Вывод о длине цикла верный.
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
# Будет гораздо нагляднее, если ты сделаешь этот анализ для 6 платформ с наибольшими продажами в истории. Чтобы получить красивую кривую нужно много данных А многие платформы не имеют большой истории. В результате для них получим что-то статистически не очень достоверное и некрасивое
#
#
# Как можно было найти средний цикл жизни платформ еще?
#
#
#
# - Создать сводную табличку (по одной оси продажи, по другой платформы, а в качестве данных продажи), сверху наложить heatmap - будет красивенько )
#
#
#
#
# - Построить графики с разбивкой по платформам (Ниже использовал, но для другой задачи)

# %% [markdown]
# Соответствнно возьмём последний актуальный период 2005-2016гг. 11 лет.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
# Взятый тобой период в более чем 5 лет плохо увязан с полученными результатами и условиями проекта. Первое: в проекте просят собрать актуальные данные для работы в 2017 году. Второе: если посмотреть на срок жизненного цикла платформы, мы увидим как буквально за считанные годы платформа появляется, достигает пика и теряет популярность. Даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит, ведь нам нужно получить хоть какие то представления о тренде.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# По вопросу жизненного цилка консолей нашёл на Дзене интересную информацию ( https://dzen.ru/media/igorpishet/kakoi-jiznennyi-cikl-imeiut-konsoli-5e7df462ae428b2874ddb4fd ). Там указаны данные по консолям с 1994 года, времени начала продаж PS1 и даже на основании этой информации. И таки да! =) Грубый рассчёт данной информации выводит на 6-летний срок жизни консоли. Жизненный срок - от начала производства до снятия с производства. <br>
# Однако на основании полученной информации выше (с 1980 по 2016 года) срок жизни 11 лет. Посмотрим полученную диаграмму ниже. С учётом получения прогноза на 2017 год возьмём отрезок с актуальных консолей на окончание 2016 года - это PS4 и XBox One. Это с 2013 года по 2016.
#
# </div>

# %%
# согдадим датасет с данными 'year_of_release' начиная с 2005 года
data_need_years = data[data['year_of_release'] >= 2005]
data_need_years.pivot_table(index='platform', columns='year_of_release', values='name', aggfunc='count', fill_value='*')
# Out:
# year_of_release   2005   2006   2007   2008   2009   2010   2011   2012  \
# platform
# 3DS                  *      *      *      *      *      *  116.0   93.0
# DC                   *      *    1.0    1.0      *      *      *      *
# DS               118.0  201.0  376.0  492.0  403.0  323.0  153.0   23.0
# GBA              135.0   39.0    6.0      *      *      *      *      *
# GC                97.0   40.0    4.0      *      *      *      *      *
# PC                37.0   52.0   62.0   76.0  107.0   90.0  139.0   61.0
# PS2              260.0  259.0  214.0  191.0   96.0   38.0    7.0      *
# PS3                  *   27.0   90.0  138.0  162.0  181.0  215.0  148.0
# PS4                  *      *      *      *      *      *      *      *
# PSP               95.0  189.0  133.0  100.0  161.0  188.0  139.0  106.0
# PSV                  *      *      *      *      *      *   18.0   53.0
# Wii                  *   44.0  185.0  282.0  325.0  253.0  143.0   31.0
# ...

# %%
# посмотрим графики продаж с разбитием по платформам с 2005 по 2016 годы
pd.pivot_table(data_need_years, index='year_of_release', columns='platform', values='all_sales', aggfunc='sum').plot(figsize=(15,10))
plt.grid(True)
plt.title('Продажи с 2005 по 2016 по платформам\n  ')
plt.xlabel('Год')
plt.ylabel('Продажи (млн. копий)')
plt.show()

# %% [markdown]
# Сделаем круг исследования уже. Возьмём 2013-2016гг.

# %%
# согдадим датасет по играм начиная с 2013 года по 2016 год
data_need_years1 = data[data['year_of_release'] >= 2013]
data_need_years1.pivot_table(index='platform', columns='year_of_release', values='name', aggfunc='count', fill_value='*')
# Out:
# year_of_release   2013   2014   2015   2016
# platform
# 3DS               91.0   80.0   86.0   46.0
# DS                 8.0      *      *      *
# PC                38.0   47.0   50.0   54.0
# PS3              126.0  108.0   73.0   38.0
# PS4               16.0   75.0  137.0  164.0
# PSP               54.0   10.0    3.0      *
# PSV               63.0  100.0  110.0   85.0
# Wii               12.0    6.0    4.0    1.0
# WiiU              42.0   31.0   28.0   14.0
# X360              75.0   63.0   35.0   13.0
# XOne              19.0   61.0   80.0   87.0

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Отличный выбор
#
#
#
#
# </div>

# %%
# график по продажам игр с разбивкой на консоли с 2013 по 2016 года
pd.pivot_table(data_need_years1, index='year_of_release', columns='platform', values='all_sales', aggfunc='sum').plot(figsize=(15,10))
plt.grid(True)
plt.title('Продажи с 2013 по 2016 по платформам\n  ')
plt.xlabel('Год')
plt.ylabel('Продажи (млн. копий)')
plt.show()

# %% [markdown]
# Продажи игр по всем консолям падают, но судя по данному графику ТОПовой консолью является PS4. Соответственно далее расположим менее популярные консоли, но тоже продаваемые.

# %% [markdown]
# Однако!

# %%
# отберём 5 популярных консолей
potential_platform = ['PS4', '3DS', 'XOne', 'WiiU', 'PSV']

# %% [markdown]
# Разъяснение:
#
# PS4 - потенциально прибыльная долгожительница (в 2022 году знаем точно =)),
#
# 3DS показывает хорошие продажи с выделенных годом, но её жизненный цикл подходит к концу,
#
# XOne - главный конкурент PS4, но видим, что продажи намного меньше, но потенциал так же велик
#
# WiiU - неплохие продажи игр, но её популярность тоже затухает
#
# PSV - ps vita хорошая портативка и в 2016 году достаточно популярна, но и она начала "погибать"

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
# Посмотрены продажи, динамика и найдены платформы которые действительно стоит рассмотреть для 2017 года. Я бы ещё добавил PC  он вечный )

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Мне кажется нет смысла добавлять PC =) Консоли совершенствуются, а мы играем в Героев 3 и CSS =) Не нужны нам эти технологии)))
#
# <img src="https://stihi.ru/pics/2018/02/24/10924.jpg">
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Я играю PC ) Стратегии там всякие )
#
#
#
#
# </div>

# %%
report = data.query('platform in @potential_platform')

# %% [markdown]
# # Задание: Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат

# %%
# делаю "ящик с усами" по 5 популярным консолям
report.boxplot('all_sales', by='platform', figsize=(15, 15))
plt.suptitle('Глобальные продажи игр в разбивке по потенциально прибыльным платформам')
plt.title(None);
plt.xlabel('Платформа'), plt.ylabel('Суммарные продажи (млн.)')
plt.ylim(0, 10)
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
# График построен верно, но есть одно важное замечание. Результат твоей работы пойдет дальше, например в отдел маркетинга, и там люди вряд ли скажут спасибо за график на котором не видны медиана и квантили. Твой график хорош тем что видны выбросы, они важны, это супермега популярные игры, которые и вытягивают продажи. Но также данный график нужен для сравнения платформ, а на твоем графике такой анализ выполнить затруднительно.
#
# Решением тут будет построить два графика, один с ограниченными данными (без выбросов, чтобы оценить квартили по платформам)  и график с полными данными (для оценки выбросов).
#
# <div class="alert alert-warning">
#
#
# Совет:
#
# почему не используешь seaborn? Он строит красивей и  код лаконичней:
#
#
#     plt.figure(figsize=(13, 8))
#     (sns.boxplot(data = df, y = 'total_sales', x='Платформы')
#         .set(title = 'Продажи по платформам', xlabel = 'Платформы', ylabel = 'Общие продажи', ylim=(0, 3)))
#
#     plt.show()

# %%
# ящики с усами версия 2.0 
plt.figure(figsize=(20,30))
box_all = sns.boxplot(x="platform", y="all_sales", data = data.query('platform in @potential_platform'), palette="Set1")
box_all.set(ylim=(0,2))
plt.ylabel('Суммарные продажи, млн.шт.')
plt.xlabel('Платформы')
plt.title('Boxplot для продаж по платформам')
plt.show()

# %% [markdown]
# Данные консоли безусловно лидеры, но самые главные лидеры по продажам - PS4 и XOne, так де достойна внимания 3Ds, но к сожалению у нас в стране она не так популярна =( (личный опыт)))

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Надеюсь теперь маркетологи будут рады =)
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Совет 🤔:
#
#
# Они будут более счастлива ) Можно было для этого графика вообще убрать выбросы
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Ошибка:
#
# Boxplot позволяет сравнивать по медианам, и сравнивать размахи.
#
# Еще boxplot позволяет сделать выводы о плотности распределения и квантилям.  Стоит добавить анализа, иначе зачем нам вообще boxplot !?
#
# Вопросы, ответы на которые помогут дополнить вывод:
#
# 1. Что общего у плотностей распределений всех платформ (обрати внимание на то к чему ближе медиана - к верхнему или нижнему квантилю)?
#
# 2. Ответив на первый вопрос, можно ли сказать - преобладают ли у нас игры с небольшими продажами и небольшим числом мегапопулярных игр, или наоборот.
#
# Чтобы лучше понять, что отображает боксплот, рекомендую со следующим материалом ознакомиться
#
# https://stepik.org/lesson/9294/step/4?unit=1827
#
# И вот рисуночек:
#
#
# ![Ящик с усами](https://ucarecdn.com/c476e686-fb7b-4e8a-b9d3-54d3b461bb44/)

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Вопрос № 1:
# Что общего у плотностей распределений всех платформ (обрати внимание на то к чему ближе медиана - к верхнему или нижнему квантилю)?
#
# Ответ: У нас получается медиана ближе к нижнему квартилю во всех случаях
#
# Вопрос № 2:
# Ответив на первый вопрос, можно ли сказать - преобладают ли у нас игры с небольшими продажами и небольшим числом мегапопулярных игр, или наоборот.
#
# Ответ: Медиана ниже к нижнему квартилю. Видимо приобладают игры с небольшими продажами и небольшим числом мегапопулярных игр.
#
# Я верно же понял?)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Верно.  Характеристика это индустрии?! Ещё какая
#
#
#
# </div>

# %% [markdown]
# # Задание: Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %%
# извлечём строки с условием 'platform == "PS4"
influence_ps4 = data.query('platform == "PS4"')

# %%
# сделаем таблицу со следующими данными 'critic_score', 'user_score', 'all_sales'
influence_ps4[['critic_score', 'user_score', 'all_sales']]
# Out:
#        critic_score  user_score  all_sales
# 31              NaN         NaN      14.63
# 42             97.0         8.3      12.62
# 77             82.0         4.3       8.58
# 87              NaN         NaN       7.98
# 92             83.0         5.7       7.66
# ...             ...         ...        ...
# 16500          69.0         7.5       0.01
# 16503           NaN         NaN       0.01
# 16526          61.0         7.9       0.01
# 16530          51.0         5.5       0.01
# 16585           NaN         NaN       0.01
#
# [392 rows x 3 columns]

# %% [markdown]
# Построим диаграмму рассеивания - соотношение 'critic_score' (отзывы критиков) и 'all_sales'(все продажи)

# %%
# диаграмма рассеивания
influence_ps4.plot.scatter (x='critic_score', y='all_sales', s= 60 , c='green')
# Out:
# <AxesSubplot:xlabel='critic_score', ylabel='all_sales'>

# %% [markdown]
# Построим диаграмму рассеивания - соотношение 'critic_score' (отзывы критиков) и 'all_sales'(все продажи)

# %%
# диаграмма рассеивания
influence_ps4.plot.scatter (x='user_score', y='all_sales', s= 60 , c='green')
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='all_sales'>

# %% [markdown]
# Рассчитаем корреляцию между столбами

# %%
# корреляция
influence_ps4[['critic_score', 'user_score', 'all_sales']].corr()
# Out:
#               critic_score  user_score  all_sales
# critic_score      1.000000    0.557654   0.406568
# user_score        0.557654    1.000000  -0.031957
# all_sales         0.406568   -0.031957   1.000000

# %%
pd.plotting.scatter_matrix(influence_ps4[['critic_score', 'user_score', 'all_sales']], figsize=(10,10));

# %% [markdown]
# Влияние отзывов в целом не столь вилеко, однако на некоторые игры они влеяют.

# %% [markdown]
# # Задание: Соотнесите выводы с продажами игр на других платформах. Выберем 4 выбранных наиболее популярные консоли в рассматриваемый период.

# %% [markdown]
# Рассмотрим консоль 3Ds:

# %%
influence_3ds = data.query('platform == "3DS"')

# %%
influence_3ds[['critic_score', 'user_score', 'all_sales']]
# Out:
#        critic_score  user_score  all_sales
# 33              NaN         NaN      14.60
# 40             85.0         8.2      12.65
# 47              NaN         NaN      11.68
# 53             90.0         8.4      10.81
# 62             78.0         7.2       9.90
# ...             ...         ...        ...
# 16648           NaN         NaN       0.01
# 16653           NaN         NaN       0.01
# 16668           NaN         NaN       0.01
# 16677           NaN         NaN       0.01
# 16688           NaN         NaN       0.01
#
# [520 rows x 3 columns]

# %%
data.query('platform == "3DS"')[['critic_score', 'user_score', 'all_sales']].corr()
# Out:
#               critic_score  user_score  all_sales
# critic_score      1.000000    0.744168   0.349401
# user_score        0.744168    1.000000   0.224808
# all_sales         0.349401    0.224808   1.000000

# %%
influence_3ds.plot.scatter (x='critic_score', y='all_sales', s= 60 , c='green')
# Out:
# <AxesSubplot:xlabel='critic_score', ylabel='all_sales'>

# %%
influence_3ds.plot.scatter (x='user_score', y='all_sales', s= 60 , c='green')
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='all_sales'>

# %%
influence_3ds[['critic_score', 'user_score', 'all_sales']].corr()
# Out:
#               critic_score  user_score  all_sales
# critic_score      1.000000    0.744168   0.349401
# user_score        0.744168    1.000000   0.224808
# all_sales         0.349401    0.224808   1.000000

# %%
pd.plotting.scatter_matrix(influence_3ds[['critic_score', 'user_score', 'all_sales']], figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='critic_score', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='all_sales', ylabel='critic_score'>],
#        [<AxesSubplot:xlabel='critic_score', ylabel='user_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='user_score'>,
#         <AxesSubplot:xlabel='all_sales', ylabel='user_score'>],
#        [<AxesSubplot:xlabel='critic_score', ylabel='all_sales'>,
#         <AxesSubplot:xlabel='user_score', ylabel='all_sales'>,
#         <AxesSubplot:xlabel='all_sales', ylabel='all_sales'>]],
#       dtype=object)

# %% [markdown]
# <b>Рассмотрим консоль XOne:</b>

# %%
influence_xone = data.query('platform == "XOne"')

# %%
influence_xone[['critic_score', 'user_score', 'all_sales']]
# Out:
#        critic_score  user_score  all_sales
# 99              NaN         NaN       7.39
# 165            97.0         7.9       5.47
# 179            81.0         5.4       5.26
# 242            84.0         6.4       4.49
# 270            88.0         6.2       4.22
# ...             ...         ...        ...
# 16630          63.0         8.2       0.01
# 16643           NaN         6.6       0.01
# 16645           NaN         NaN       0.01
# 16660          74.0         6.7       0.01
# 16672           NaN         NaN       0.01
#
# [247 rows x 3 columns]

# %%
influence_xone.query('platform == "XOne"')[['critic_score', 'user_score', 'all_sales']].corr()
# Out:
#               critic_score  user_score  all_sales
# critic_score      1.000000    0.472462   0.416998
# user_score        0.472462    1.000000  -0.068925
# all_sales         0.416998   -0.068925   1.000000

# %%
influence_xone.plot.scatter (x='critic_score', y='all_sales', s= 60 , c='green')
# Out:
# <AxesSubplot:xlabel='critic_score', ylabel='all_sales'>

# %%
influence_xone.plot.scatter (x='user_score', y='all_sales', s= 60 , c='green')
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='all_sales'>

# %%
influence_xone[['critic_score', 'user_score', 'all_sales']].corr()
# Out:
#               critic_score  user_score  all_sales
# critic_score      1.000000    0.472462   0.416998
# user_score        0.472462    1.000000  -0.068925
# all_sales         0.416998   -0.068925   1.000000

# %%
pd.plotting.scatter_matrix(influence_xone[['critic_score', 'user_score', 'all_sales']], figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='critic_score', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='all_sales', ylabel='critic_score'>],
#        [<AxesSubplot:xlabel='critic_score', ylabel='user_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='user_score'>,
#         <AxesSubplot:xlabel='all_sales', ylabel='user_score'>],
#        [<AxesSubplot:xlabel='critic_score', ylabel='all_sales'>,
#         <AxesSubplot:xlabel='user_score', ylabel='all_sales'>,
#         <AxesSubplot:xlabel='all_sales', ylabel='all_sales'>]],
#       dtype=object)

# %% [markdown]
# Рассмотрим консоль WiiU:

# %%
# датафрейм с с данными по консоли WiiU
influence_wiiu = data.query('platform == "WiiU"')
influence_wiiu.head()

# %%
# корреляция
influence_wiiu.query('platform == "WiiU"')[['critic_score', 'user_score', 'all_sales']].corr()
# Out:
#               critic_score  user_score  all_sales
# critic_score       1.00000    0.770080   0.348380
# user_score         0.77008    1.000000   0.400219
# all_sales          0.34838    0.400219   1.000000

# %%
# диаграмма рассеивания
influence_wiiu.plot.scatter (x='critic_score', y='all_sales', s= 60 , c='green');

# %%
# диаграмма рассеивания
influence_wiiu.plot.scatter (x='user_score', y='all_sales', s= 60 , c='green');

# %%
pd.plotting.scatter_matrix(influence_wiiu[['critic_score', 'user_score', 'all_sales']], figsize=(10,10));

# %% [markdown]
# Рассмотрим консоль PSV

# %%
# датасет с информацией о консоли PSV
influence_psv = data.query('platform == "PSV"')
influence_psv.head()

# %%
# корреляция
influence_psv.query('platform == "PSV"')[['critic_score', 'user_score', 'all_sales']].corr()
# Out:
#               critic_score  user_score  all_sales
# critic_score      1.000000    0.733471   0.131517
# user_score        0.733471    1.000000   0.013580
# all_sales         0.131517    0.013580   1.000000

# %%
# диаграмма рассеивания
influence_psv.plot.scatter (x='critic_score', y='all_sales', s= 60 , c='green');

# %%
influence_psv.plot.scatter (x='user_score', y='all_sales', s= 60 , c='green');

# %%
pd.plotting.scatter_matrix(influence_psv[['critic_score', 'user_score', 'all_sales']], figsize=(10,10));

# %% [markdown]
# Вывод: Исходя из моего анализа - на остальные консоли '3DS', 'XOne', 'WiiU', 'PSV'. Больше всего отзывов критиков и пользователей получили игры консоли XOne и PSV. На мой взгляд это может быть связано с рекламной компанией.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
#
#
#
# + графики оформлены аккуратно
#
# + метод .corr() использован
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
# - Когда действие повторяется два и более раз, стоит подумать о цикле или функции или функции с циклом
#
#
# - sns.pairplot можно использовать, будет красивей .scatter_matrix
#
# - Просто сказать о отрицательной или положительной корреляции не достаточно, стоит общаться в относительных категориях:  сильная корреляционная связь (положительная или отрицательная), средняя, слабая, или отсутствие какой бы то не было корреляции.
#
# Можно воспользоваться этой шпаргалкой
#
# ![avatar](https://www.ok-t.ru/studopediaru/baza17/1942458671852.files/image012.gif)
#
#
#
# Вопросики, пожеланию можешь ответить )
#
#
#
# - Можешь предположить почему корреляция продаж с отзывами критиков выше, чем с отзывами пользователей?
#
#
# - Можешь вспомнить, только какой тип связи может выявить корреляция Пирсона?
#
#
# - Можно ли утверждать о отсутствии связи при близких к нулю показателях корреляции?
#
#
# - Можно ли утверждать о причинно-следственной связях при высоких значениях корреляции?
#
#
# - Можешь используя графики выявить нелинейные связи?
#
#
#
#
# </div>

# %% [markdown]
# # Задание: Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Ошибка ❌:
#
#
#
# Я бы советовал её всеми согласными вставить `#`,  и тогда у нас будет сквозная нумерация (или по крайней мере отмечать пункты жирным, как ты это делал выше)
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Совет 🤔:
#
# Не так написал
#
# `##` надо ставить чтобы появилась сквозная нумерация.
#
# </div>

# %%
# датасет с ТОП 5 консолей
best5_platform_name = ['PS4', '3DS', 'XOne', 'WiiU', 'PSV']

# %%
# жанры игр
genre1 = data_need_years1.query('platform in @best5_platform_name')
genre1.head()

# %%
# посмотрим самые популярные жанры игр
genre1['genre'].value_counts()
# Out:
# Action          518
# Role-Playing    210
# Adventure       158
# Sports          114
# Misc            108
# Shooter          90
# Platform         53
# Fighting         46
# Racing           44
# Simulation       29
# Strategy         29
# Puzzle           16
# Name: genre, dtype: int64

# %%
# сгруппируем данные данров по продажам и наименований игр 
genre2 = genre1.groupby(['genre']).agg({'all_sales':'sum', 'name':'count'})
genre2
# Out:
#               all_sales  name
# genre
# Action           191.92   518
# Adventure         15.97   158
# Fighting          26.59    46
# Misc              33.95   108
# Platform          34.15    53
# Puzzle             3.13    16
# Racing            29.39    44
# Role-Playing     119.07   210
# Shooter          155.87    90
# Simulation        11.70    29
# Sports            88.71   114
# Strategy           3.88    29

# %%
# диаграмма зависимости продаж от жанра
genre2.plot(kind='bar')                         
plt.title('Зависимость продаж от жанра игр')
plt.ylabel('Суммарные продажи, млн.проданных копий')
plt.xlabel('Жанр игры')
plt.show()

# %% [markdown]
# Безусловно лидер продаж - жанр Action. Далее по популярности идёт Adventure, ну и так далее.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
# - Верно ли ограничиваться сравнением суммарных продаж по жанрам?! На какие множители можно разложить полученный результат?! Это средняя продажа игр в этом жанре на количество игр в этом жанре. То есть за высокими продажами какого-то жанра могут скрываться множество мелких игры, с низкими продажами. А за низкими суммарными продажами в жанре может скрываться небольшое число игры, но каждая из которых имеет высокие доходы.  Посмотри на средние продажи (aggfunc='mean') и оцени, как поменяются лидеры.
#
#
#
# - Используем датасет с актуальными годами. Потому что наша задача дать рекомендации на 2017 год, а для этого нам не  нужны годы с неактуальными тенденцими.
#
#
# </div>

# %%
# средние продажи по жанрам
genre_pivot = genre1.pivot_table(index='genre', values=['all_sales'],aggfunc='mean')
genre_pivot
# Out:
#               all_sales
# genre
# Action         0.370502
# Adventure      0.101076
# Fighting       0.578043
# Misc           0.314352
# Platform       0.644340
# Puzzle         0.195625
# Racing         0.667955
# Role-Playing   0.567000
# Shooter        1.731889
# Simulation     0.403448
# Sports         0.778158
# Strategy       0.133793

# %%
# график средних продаж
genre_pivot.plot(kind='bar')                         
plt.title('Средние продажи')
plt.ylabel('Суммарные продажи, млн.проданных копий')
plt.xlabel('Жанр игры')
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Мда. Действительно средние продажи показали изменения. Жанры: Shooter, Sports, Racing, Platform и т.д.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# А игры жанра Action имеет довольно средний показатель продаж.  Смотреть средние важно потому что мы продаём конкретные игры, а не жанры
#
#
#
# </div>

# %% [markdown]
# # Задание: Составьте портрет пользователя каждого региона. Определите для пользователя каждого региона (NA, EU, JP):

# %%
# портрет пользователя
region1 = data_need_years1.query('platform in @best5_platform_name')
region1.head()

# %%
# портрет пользователя региона 'na'
region2 = region1.groupby(['platform']).agg({'na_sales':'sum'})
region2.sort_values(by = 'na_sales', ascending=False)
# Out:
#           na_sales
# platform
# PS4         108.74
# XOne         93.12
# 3DS          38.20
# WiiU         29.21
# PSV           5.04

# %%
region_na = region1.groupby(['platform']).agg({'na_sales':'sum'}).reset_index()
region_na.sort_values(by='na_sales', ascending=False)
# Out:
#   platform  na_sales
# 1      PS4    108.74
# 4     XOne     93.12
# 0      3DS     38.20
# 3     WiiU     29.21
# 2      PSV      5.04

# %%
region_eu = region1.groupby(['platform']).agg({'eu_sales':'sum'})
region_eu.sort_values(by='eu_sales', ascending=False)
# Out:
#           eu_sales
# platform
# PS4         141.09
# XOne         51.59
# 3DS          30.96
# WiiU         19.85
# PSV           6.10

# %%
region_jp = region1.groupby(['platform']).agg({'jp_sales':'sum'})
region_jp.sort_values(by='jp_sales', ascending=False)
# Out:
#           jp_sales
# platform
# 3DS          67.81
# PSV          18.59
# PS4          15.96
# WiiU         10.88
# XOne          0.34

# %%
region_other_sales = region1.groupby(['platform']).agg({'other_sales':'sum'})
region_other_sales.sort_values(by='other_sales', ascending=False)
# Out:
#           other_sales
# platform
# PS4             48.35
# XOne            14.27
# 3DS              6.28
# WiiU             4.69
# PSV              3.26

# %% [markdown]
# По всем регионам в целом в приоритете остаётся PS4, далее XOne, но в Японском регионе почему-то в приоритете оказалась 3DS и с большим отрывом PSV. Наверное они любят портативки =)

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Совет 🤔:
#
#
# Тут бы не помешал график. Причём когда ты строишь несколько однотипных графика, то можно использовать [subplots](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html). Это когда мы берем один "холст" на котором размещаем нужные нам графики рядом друг с другом. Это и визуально выглядит лучше и возможность строить однотипные графики в цикле. Тут бы это хорошо подошло.
# </div>

# %% [markdown]
# # 4 Задача: Самые популярные жанры (топ-5). Поясните разницу.

# %%
best5_platform_name = ['PS4', '3DS', 'XOne', 'WiiU', 'PSV']

# %%
genre1 = data_need_years1.query('platform in @best5_platform_name')
genre1.head()
# Out:
#                                          name platform  year_of_release  \
# 31                  Call of Duty: Black Ops 3      PS4             2015
# 33                        Pokemon X/Pokemon Y      3DS             2013
# 42                         Grand Theft Auto V      PS4             2014
# 47  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 77                                    FIFA 16      PS4             2015
#
#            genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 31       Shooter      6.03      5.86      0.36         2.38           NaN
# 33  Role-Playing      5.28      4.19      4.35         0.78           NaN
# 42        Action      3.96      6.31      0.38         1.97          97.0
# 47  Role-Playing      4.35      3.49      3.10         0.74           NaN
# 77        Sports      1.12      6.12      0.06         1.28          82.0
#
#     user_score                       rating  all_sales
# ...

# %%
genre_na = genre1.groupby(['genre']).agg({'na_sales':'sum'})
genre_na.sort_values(by='na_sales', ascending=False)
# Out:
#               na_sales
# genre
# Shooter          72.12
# Action           71.17
# Sports           36.98
# Role-Playing     36.16
# Platform         14.17
# Misc             12.33
# Fighting         12.09
# Racing           10.25
# Adventure         4.54
# Simulation        2.40
# Strategy          1.27
# Puzzle            0.83

# %%
genre_na = genre1.groupby(['genre']).agg({'eu_sales':'sum'})
genre_na.sort_values(by='eu_sales', ascending=False)
# Out:
#               eu_sales
# genre
# Action           69.46
# Shooter          59.09
# Sports           36.89
# Role-Playing     29.24
# Racing           14.31
# Platform         12.10
# Misc             10.32
# Fighting          6.49
# Adventure         5.42
# Simulation        4.36
# Puzzle            1.00
# Strategy          0.91

# %%
genre_jp = genre1.groupby(['genre']).agg({'jp_sales':'sum'})
genre_jp.sort_values(by='jp_sales', ascending=False)
# Out:
#               jp_sales
# genre
# Role-Playing     44.84
# Action           29.87
# Misc              8.27
# Fighting          5.33
# Platform          4.75
# Shooter           4.56
# Adventure         4.37
# Simulation        4.29
# Sports            3.05
# Racing            1.68
# Strategy          1.43
# Puzzle            1.14

# %%
genre_other_sales = genre1.groupby(['genre']).agg({'other_sales':'sum'})
genre_other_sales.sort_values(by='other_sales', ascending=False)
# Out:
#               other_sales
# genre
# Action              21.42
# Shooter             20.10
# Sports              11.79
# Role-Playing         8.83
# Racing               3.15
# Platform             3.13
# Misc                 3.03
# Fighting             2.68
# Adventure            1.64
# Simulation           0.65
# Strategy             0.27
# Puzzle               0.16

# %% [markdown]
# Всём мире в целом одно и тоже - Action да Shooter. Японцы опять пыделились. У них Role-Playing на перовм месте. Потом только Action. Япония - отдельный мир!

# %% [markdown]
# Задача:Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
best5_platform_name = ['PS4', '3DS', 'XOne', 'WiiU', 'PSV']

# %%
esrb = data_need_years1.query('platform in @best5_platform_name')

# %%
esrb_all_region = (esrb.pivot_table(index='rating', values=['na_sales', 'eu_sales', 'jp_sales'],aggfunc='sum'))
esrb_all_region
# Out:
#                              eu_sales  jp_sales  na_sales
# rating
# E                               54.68     13.26     52.23
# E10+                            24.31      5.66     31.42
# M                               84.15      8.17     91.03
# T                               26.93     13.52     31.85
# no_information_about_rating     59.52     72.97     67.78

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
# Следствие ошибка, которая была допущена, при не заполнении пропусков в столбце "rating": на графиках не отобразились данные о играх без рейтинга, но продажи именно этих игр могут указать на ключевое различие в регионах или поменять пропорции. Стоит заполнить пропуски в столбце "rating", каким то смысловым маркером и пересчитать результаты, при необходимости поправив выводы.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Поправил. Теперь отображаются.
#
#
# </div>

# %%
esrb_na = esrb.groupby(['rating']).agg({'na_sales':'sum'})
esrb_na.sort_values(by='na_sales', ascending=False)
# Out:
#                              na_sales
# rating
# M                               91.03
# no_information_about_rating     67.78
# E                               52.23
# T                               31.85
# E10+                            31.42

# %%
esrb_eu = esrb.groupby(['rating']).agg({'eu_sales':'sum'})
esrb_eu.sort_values(by='eu_sales', ascending=False)
# Out:
#                              eu_sales
# rating
# M                               84.15
# no_information_about_rating     59.52
# E                               54.68
# T                               26.93
# E10+                            24.31

# %%
esrb_jp = esrb.groupby(['rating']).agg({'jp_sales':'sum'})
esrb_jp.sort_values(by='jp_sales', ascending=False)
# Out:
#                              jp_sales
# rating
# no_information_about_rating     72.97
# T                               13.52
# E                               13.26
# M                                8.17
# E10+                             5.66

# %%
esrb_other_sales = esrb.groupby(['rating']).agg({'other_sales':'sum'})
esrb_other_sales.sort_values(by='other_sales', ascending=False)
# Out:
#                              other_sales
# rating
# M                                  27.33
# no_information_about_rating        17.84
# E                                  14.54
# T                                   9.71
# E10+                                7.43

# %% [markdown]
# Лидер рейтинга M в целом схож по всем исслдуемым регионам, но Япония как обычно выбилась из общей колии с рейтингом E в лидерах.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Япония на своей волне ) И жанры другие и платформы и доля играющих среди тинейджеров выше
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Обновлю вывод:<br>
#
# Ну опять не для рекламы - просто в японскую тему https://www.youtube.com/watch?v=r_l0QkYpJos Консолей на любой вкус и цвет можно купить) Для любителей ретро игр прям таки рай)))
#
# После добавления 'no_information_about_rating' очевидно, что данный пункт в лидерах по всем регионам. Ну не присвоили играм рейтинг ESRB. Ну не в фаворе в Японии этот рейтинг и всё тут =)
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
# Принято.
#
#
# Видим что для многих игр отсутствует рейтинг, особенно характерно это для японского региона, из этого можно сделать вывод о необходимости дополнительного сбора информации, для корректного ответа на вопрос о взаимосвязи рейтинга и продаж. Я вижу так )
#
#
# А почему пропуски - писал выше
#
#
#
#
# </div>

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0     28.96      3.77         8.45          76.0         8.0
# 1      3.58      6.81         0.77           NaN         NaN
# 2     12.76      3.79         3.29          82.0         8.3
# 3     10.93      3.28         2.95          80.0         8.0
# 4      8.89     10.22         1.00           NaN         NaN
#
#                         rating  all_sales
# 0                            E      82.54
# 1  no_information_about_rating      40.24
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
#
#
#
#
#
# - Допустим мы хотим cделать группировку и вывести в процентах. Мы можем взять сумму (sum), среднюю (mean)...но чтобы сделать проценты, придётся поработать похитрее (схема):
#
#         (df_current
#         .groupby('platform')[['na_sales', 'eu_sales', 'jp_sales']]
#         .agg('sum')
#         .apply(lambda x: round(x / float(x.sum()), 2))     # вот это считает проценты
#         ).reset_index()
#
#
# Лямбда функция это очень просто, ты ведь знаешь про самописные функции? Так вот лямбда это "функция на лету", можно написать функцию, а можно лямбду, аналогии очевидны:
#
#         def add_(x):
#             return x+3
#
# и аналог
#
#         lambda x: x+3
#
# Как видишь мы не создаем функцию, не присваиваем ей имя, не пишем return, мы просто быстренько сделали неименованную функцию - лямбду, потому что больше она нам не понадобиться, а аргумент x и там и там один и тот же и делаем мы с ним одно и тоже.
#
#
#
# - Рейтинги `E`, `T`, `K-A` итд  могут нам ничего не говорить,  тавай сделаем замену: E  ----->  Для всех, M ------>   17 лет итп. Обычно используют для этого словарь с заменами и .map (схема):
#
#
#
#         ESRB_dict = {'E': 'Для всех', 'M': '> 17 лет', 'T': '13-19 лет', 'E10+': '>10 лет', 'K-A': 'Для всех', 'unknown': 'Не известен',....}
#         df_current['ESRB_description'] = df_current['rating'].map(ESRB_dict)
#
#
#
#
#
#
#
#
# Это не обязательное требование, если есть желание можешь попробовать что то реализовать, нет - я приму работу и так ;)
#
#
# </div>

# %% [markdown]
# 5. Проверьте гипотезы

# %% [markdown]
# # Задание: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;

# %%
#Данные для проверки гипотезы
xone = data_need_years1.query(' platform == "XOne" ')['user_score'].dropna().to_list()
pc = data_need_years1.query(' platform == "PC" ')['user_score'].dropna().to_list()

#Рассчитаем средние значения
xone_mean = data_need_years1.query(' platform == "XOne" ')['user_score'].mean()
pc_mean = data_need_years1.query(' platform == "PC" ')['user_score'].mean()

print('Средний пользовательский рейтинг Xbox One: {:.3}\n'
     'Средний пользовательский рейтинг PC: {:.2}'.format(xone_mean, pc_mean))
# Out:
# Средний пользовательский рейтинг Xbox One: 6.52
# Средний пользовательский рейтинг PC: 6.3

# %% [markdown]
# Вывод: Средние пользовательские рейтинги Xbox One и PC почти равны.

# %% [markdown]
# # Задание: Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %%
#Данные для проверки гипотезы
action = data_need_years1.query('genre == "Action"')['user_score'].dropna().to_list()
sports = data_need_years1.query('genre == "Sports"')['user_score'].dropna().to_list()

#Рассчитаем средние значения
action_mean = data_need_years1.query('genre == "Action"')['user_score'].mean()
sports_mean = data_need_years1.query('genre == "Sports"')['user_score'].mean()

print('Средний пользовательский рейтинг Action: {:.3}\n'
     'Средний пользовательский рейтинг Sports: {:.2}'.format(action_mean, sports_mean))
# Out:
# Средний пользовательский рейтинг Action: 6.84
# Средний пользовательский рейтинг Sports: 5.2

# %% [markdown]
# Вывод: Средний пользовательский рейтинг жанров Action и Sports расходится. Action популярнее Sports.

# %% [markdown]
# Задайте самостоятельно пороговое значение alpha.

# %% [markdown]
# H0: cредние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# H1: средние пользовательские рейтинги платформ Xbox One и PC различаются
#
# Используем метод scipy.stats.ttest_ind (array1, array2, equal_var = False). False, потому что дисперсии наших выборок отличаются примерно на 27%. Критический уровень значимости 0.05. Пусть вероятность правильности вывода будет 99% и больше

# %%
alpha = .05

results = st.ttest_ind(
    xone, 
    pc,
    nan_policy='omit', 
    equal_var = False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.14759594013430463
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Используем метод scipy.stats.ttest_ind (array1, array2, equal_var = False). False, потому что дисперсии наших выборок отличаются примерно на 34%. Критический уровень значимости 0.05. Пусть вероятность правильности вывода будет 99% и больше

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
#
# Правильно:
#
# + сформулирована нулевая и альтернативные гипотезы
#
# + правильно выбрана статистика
#
# + метод
#
# + equal_var=False
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
# перед подачей данных убраны пропуски, альтернатива в st.ttest_ind() подать аргумент nan_policy='omit'. А ты получается одновременно использовал и то и это. Такое дублирование можно убрать
# </div>

# %%
alpha = .05

results = st.ttest_ind(
    action, 
    sports, 
    equal_var = False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.4460039700704315e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Выводы точные, без глупостей: "подтвердили гипотезу..", "выяснили что рейтинги равны/неравны.." )
#
#
# </div>

# %% [markdown]
# Вывод:
#
# 1) Судя по полученной инфрмации можно сделать вывод, что с 1980 по 1990 годы релизов было намного меньше. Видимо в данный период были проблемы с релизом, да и в целом с технологией производства видеоигр.
#
# 2) ТОП-10 продаж консолей по всему миру c 1980 по 2016. Самая популярная, ожидаемо, PS2. Далее идут X360, PS3, Wii, DS, PS, GBA, PS4, PSP, PC
#
# 3) ТОП продаж по консолям - лучшие года по продажам 2008-2009.
#
# 4) Платформы живут где-то 11 лет. Возьмём эту цифру за рассчётную(актуальную). Ожидаемо, что PC самая живучая платформа с видеоиграми, но в виду особенности консольного рынка - много классных эксключизивов выходит на оперделённой платформе, а потом уже на остальных (через 1 год или более).
#
# 5) Продажи игр по всем консолям падают, но судя по данному графику ТОПовой консолбю вляется PS4. Соответственно далее расположем менее популярные консоли, но тоже продаваемые.
#
# 6) По PS 4 влияние отзывов в целом не столь вилеко, однако на некоторые игры они влеяют.
#
# 7) На остальные консоли '3DS', 'XOne', 'WiiU', 'PSV'. Больше всего отзывов критиков и пользователей получили игры консоли XOne и PSV. На мой взгляд это может быть связано с рекламной компанией.
#
# 8) Безусловно лидер продаж - жанр Action. Далее по популярности идёт Adventure, ну и так далее.
#
# 9) По всем регионам в целом в приоритете остаётся PS4, далее XOne, но в Японском регионе почему-то в приоритете оказалась 3DS и с большим отрывом PSV. Наверное они любят портативки =)
#
# 10) Всём мире в целом одно и тоже - Action да Shooter. Японцы опять пыделились. У них Role-Playing на перовм месте. Потом только Action. Япония - отдельный мир!
#
# 11) Лидер рейтинга M в целом схож по всем исслдуемым регионам, но Япония как обычно выбилась из общей колии с рейтингом E в лидерах.
#
# 12) Средние пользовательские рейтинги Xbox One и PC почти равны.
#
# 13) Средний пользовательский рейтинг жанров Action и Sports расходится. Action популярнее Sports.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Хороший, по делу, "без воды" вывод.
#
# Но после исправления красных комментариев выше, стоит ещё раз пробежать его взглядом.
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
# - Я бы советовал структурировать общий вывод, разбив его на подразделы: работа с данными, ананлиз корреляций, проверка гипотез итд итп
#
#
# - В общем выводе идеально было бы кратко расписать данные и все проделанные шаги по работе с ними. Почему это важно? Когда проект захочет посмотреть будущий работодатель, у него может не быть времени на подробный разбор кода. Вероятнее всего он бегло просмотрит код, но захочет изучить результат, который будет в общем выводе. Поэтому все же советую написать общий вывод побьемней (добавить пару слов о данных, работе с ними), чтобы он соответствовал твоей классной работе.
#
#
#
# - Не хватает рекомендаций магазину видеоигр, для которого мы проводили исследование. Подумай пожалуйста как их можно сформулировать, на каких платформах, жанрах им нужно сконцентрироваться?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Самое большое впечатление от твоего проекта - старательность при выполнении работы над ним, не пожалел ни времени, ни усилий. Очень тщательный подход к очистке данных, бережное отношение к ним, буквально ничего не пропало. Все промежуточные и основные выводы сделаны, инструменты и методы модуля использованы оптимально.
#
# Графики оформлены корректно, title, xlabel, ylabel присутствуют, ничего не пропущено, виден подбор bins, где это требуется стоят легенды.
#
#
#
# Василий, отмечаю уровень твоей программистской подготовки, - ты используешь продвинутые концепции языка Python и библиотеки pandas, всё это делает более читабельным твой код и одновременно показывает твой уровень владения инструментами.
#
#
#
#
# Советую пользоваться возможностями питона, который позволяет избегать излишнее использование циклов, apply, map итп. Питон вообще такой язык, на котором, если поискать, почти всегда найдется метод или библиотека чтобы написать решение чуть ли не в одну строчку. Не всегда такое возможно, но стремиться стоит.
#
#
#
#
# С комментированием кода тоже никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей.
#
#
#
#
#
#
# Остались небольшие недоработки. Стоит доделать:
#
#
# - Некоторые заглавия разделов у тебя потерялись, выдели их через `#`
#
# - Не забываем хорошо начать - `вступление в работу` очень важно
#
# - Заполнить пропуски в `rating`, чтобы получить корректный результат при анализе влияния `rating` на продажи.
#
# - Стоит подобрать другие `актуальные годы`, с учетом моего комментария.
#
# - Исправить `график boxplot`  с соответствии с моими комментариями
#
# - Дополнить `вывод` по boxplot
#
# - Добавить анализ `средних` продаж по жанрам.
#
# - "В свете вновь открывшихся обстоятельств" `поправить` выводы где это необходимо
#
#
# Уверен, тебе не составит большого труда внести исправления. Жду их, для принятия проекта. Удачи 😀
#
# </div>

# %% [markdown]
# 1) Судя по полученной информации, можно сделать вывод, что с 1980 по 1990 годы релизов было намного меньше. Видимо в данный период были проблемы с релизом, да и в целом с технологией производства видеоигр.
#
# 2) ТОП-10 продаж консолей по всему миру получился. Самая популярная, ожидаемо, PS2.
#
# 3) Лучшие года по продаже консолей: 2008-2009.
#
# 4) Платформы живут где-то 11 лет. Возьмём эту цифру за расчётную (актуальную). Ожидаемо, что PC самая живучая платформа с видеоиграми, но в виду особенности консольного рынка - много классных эксклюзивов выходит на определённой платформе, а потом уже на остальных (через 1 год или более).
#
# 5) Продажи игр по всем консолям падают, но судя по данному графику ТОПовой консолью является PS4. Соответственно далее расположим менее популярные консоли, но тоже продаваемые.
#
# Разъяснение:
#
# PS4 - потенциально прибыльная долгожительница (в 2022 году знаем точно =)),
# 3DS показывает хорошие продажи с выделенных годом, но её жизненный цикл подходит к концу,
# XOne - главный конкурент PS4, но видим, что продажи намного меньше, но потенциал так же велик
# WiiU - неплохие продажи игр, но её популярность тоже затухает
# PSV - ps vita хорошая портативка и в 2016 году достаточно популярна, но и она начала "погибать"
#
# 6) Данные консоли безусловно лидеры, но самые главные лидеры по продажам - PS4 и XOne, так де достойна внимания 3Ds, но к сожалению у нас в стране она не так популярна.
#
# 7) Преобладают игры с небольшими продажами и небольшим числом мегапопулярных игр.
#
# 8) По PS4 - Влияние отзывов в целом не столь велико, однако на некоторые игры они влияют.
#
# 9) Исходя из моего анализа - на остальные консоли '3DS', 'XOne', 'WiiU', 'PSV'. Больше всего отзывов критиков и пользователей получили игры консоли XOne и PSV. На мой взгляд это может быть связано с рекламной компанией.
#
# 10) Безусловно лидер продаж - жанр Action. Далее по популярности идёт Adventure, ну и так далее.
#
# 11) Средние продажи показали изменения. Жанры: Shooter, Sports, Racing, Platform и т.д.
#
# 12) По всем регионам в целом в приоритете остаётся PS4, далее XOne, но в Японском регионе почему-то в приоритете оказалась 3DS и с большим отрывом PSV. Наверное они любят портативки =)
#
# 13) Всём мире в целом одно и тоже - Action да Shooter. Японцы опять выделились. У них Role-Playing на первом месте. Потом только Action. Япония - отдельный мир!
#
# 14) Лидер рейтинга M в целом схож по всем исследуемым регионам, но Япония как обычно выбилась из общей колеи с рейтингом E в лидерах. После добавления 'no_information_about_rating' очевидно, что данный пункт в лидерах по всем регионам. Ну не присвоили играм рейтинг ESRB.
#
# 15) Средние пользовательские рейтинги Xbox One и PC почти равны.
#
# 16) Средний пользовательский рейтинг жанров Action и Sports расходится. Action популярнее Sports.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
# Успех 👍:
#
# Общий вывод расписан
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
# Спасибо за работу!
#
#
#
# Красного нет, вопросов нет, значит все, пора принимать) Надеюсь мои советы и вопросики были полезны и в копилочку знаний упало что то новое, а проект стал лучше, и симпатичней.
#
#
# Отличная работа Василий. Желаю успехов в дальнейшей учебе!
#
#
# Ниже напишу тебе код с использованием    subplots, возможно в будущем пригодится
#
# </div>
