# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b><br>
#
# Уважаемая Александра! Большое Вам спасибо за ревью. Пишу заранее зная, что уйду на повторное ревью. Сижу, пыхчу уже целый вечер. Уже поздно. Завтра на работу рано вставать. С практикумом семья меня уже забыла как я в лицо выгляжу 🤣. Прошу посмотреть что я наделал / доделал/ переделал на данный момент. Знаю, что недодела презентацию) После проверки доделаю обязательно! и на третьем ревью обязательно всё сдам! =)) ЗЫ - все жёлтые коментарии видел! Если получится по времени - учту по максимуму. Дедлайн дышит в спину)) </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №2:</b>
#
# Василий, привет!
#
# Спасибо за внесения правок 😊  Понимаю, сочетать работу-семью-учебу задача не самая простая, а в сутках всего 24 часа😅
#
# ***
#
# Проект проверен, осталось доработать только два вопроса)
#
# Новые комментарии будут обозначены, как: **Комментарий ревьюера №2**
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №2:</b><br>
#
# Уважаемая Александра! Надеюсь, сделал верно! Если да, то заранее спасибо Вам за проверку этого .... ну как казать) "Творения". Честно говоря, я старался. Почти не подсматривал к коллегам и это почти моё личное творение. С каждым проектом становлюсь всё увереннее. Чувствую силу, как бы сказал учитель Ёда - "Да прибудет с нами сила".<br>
#
# * Про презентацию замечания учёл. Не успеваю переделать. Опять завтра на работу, а делаю опять поздно вечером(( Глаза закрываются и голова не варит.<br>
#
# ** и ещё - я не "ною")))) просто хочется поделиться ощущениями с профессионалом и лишний раз пообщаться. К сожалению моё окружение не понимает ничего в программировании и анализе данных. Не с кем пообщаться на данные темы и сообщить о проблемах и успехах.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №3:</b>
#
# Василий, привет!
#
# Проект действительно очень объемный - много заданий, графиков, карт..
# Но ты молодец, очень хорошо справился!
#
# Рекомендую только посмотреть вопрос **Рассмотрите и изобразите соотношение сетевых и несетевых заведений в датасете. Каких заведений больше?**, там я добавила комментарий и пример кода, как еще посчитать можно))
#
# Что касается круга единомышленников в аналитике - это и правда очень важно, чтобы поддерживать мотивацию и интерес к области, ну и в целом - делиться и приобретать новый опыт. В этом вопросе сообщество Практикума помогает, есть еще разные ТГ-канаты по аналитике. А также знаменитое сообщество open data science (по аналитике и DS) - https://ods.ai/, у них и youtub-канал есть с разными подборками.
#
# ***
#
# PS - Новые комментарии будут обозначены, как: **Комментарий ревьюера №3**
# </div>

# %% [markdown]
# **Василий, привет!**
#
# Меня зовут Соколова Александра, я буду проверять твой проект. Приятно познакомиться:)
#
# Предлагаю общаться на «ты», но если тебе не очень комфортно - дай, пожалуйста, знать.
#
# Ты уже проделал большую работу над проектом, давай сделаем его еще лучше. Ниже ты найдешь мои комментарии, пожалуйста, не перемещай, не изменяй и не удаляй их. Давай использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b> Так выделены самые важные замечания, их нужно обязательно проработать. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b> Так выделены небольшие замечания, некритичные ошибки или развивающие рекомендации на будущее.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b> Все отлично:) </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from plotly import graph_objects as go
from folium.plugins import MarkerCluster

# %% [markdown]
# ### Описание проекта
# - Инвесторы из фонда «Shut Up and Take My Money» решили попробовать себя в новой области и открыть заведение общественного питания в Москве. Заказчики ещё не знают, что это будет за место: кафе, ресторан, пиццерия, паб или бар, — и какими будут расположение, меню и цены.
# - Для начала они просят вас — аналитика — подготовить исследование рынка Москвы, найти интересные особенности и презентовать полученные результаты, которые в будущем помогут в выборе подходящего инвесторам места.
# - Постарайтесь сделать презентацию информативной и лаконичной. Её структура и оформление сильно влияют на восприятие информации читателями вашего исследования. Выбирать инструменты (matplotlib, seaborn и другие) и типы визуализаций вы можете самостоятельно.
# - Вам доступен датасет с заведениями общественного питания Москвы, составленный на основе данных сервисов Яндекс Карты и Яндекс Бизнес на лето 2022 года. Информация, размещённая в сервисе Яндекс Бизнес, могла быть добавлена пользователями или найдена в общедоступных источниках. Она носит исключительно справочный характер.

# %% [markdown]
# <b>name</b> — название заведения;<br>
# <b>address </b>— адрес заведения;<br>
# <b>category</b> — категория заведения, например «кафе», «пиццерия» или «кофейня»;<br>
# <b>hours</b> — информация о днях и часах работы;<br>
# <b>lat </b>— широта географической точки, в которой находится заведение;<br>
# <b>lng</b> — долгота географической точки, в которой находится заведение;<br>
# <b>rating </b>— рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — 5.0);<br>
# <b>price</b> — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее;<br>
# <b>avg_bill</b> — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:<br>
# «Средний счёт: 1000–1500 ₽»;<br>
# «Цена чашки капучино: 130–220 ₽»;<br>
# «Цена бокала пива: 400–600 ₽».<br>
# и так далее;<br>
# <b>middle_avg_bill</b> — число с оценкой среднего чека, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Средний счёт»:<br>
# Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
# Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
# Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.<br>
# <b>middle_coffee_cup</b> — число с оценкой одной чашки капучино, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Цена одной чашки капучино»:
# Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
# Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
# Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.
# <b>chain</b> — число, выраженное 0 или 1, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):
# <b>0</b> — заведение не является сетевым
# <b>1 </b>— заведение является сетевым<br>
# <b>district</b> — административный район, в котором находится заведение, например Центральный административный округ;<br>
# <b>seats</b> — количество посадочных мест.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Молодец, что подготовил введение 👍 Хорошее начало!
#
# ***
#
# На будущее - можно дополнить итогами исследования. Когда размещаешь свою работу (например, на Github), hr-специалисты часто знакомятся с вводной частью в первую очередь.

# %% [markdown]
# # Шаг 1. Загрузите данные и изучите общую информацию

# %% [markdown]
# - Загрузите данные о заведениях общественного питания Москвы. Путь к файлу: /datasets/moscow_places.csv. Скачать датасет. <br>Изучите общую информацию о датасете. Сколько заведений представлено?<br> Что можно сказать о каждом столбце? <br>Значения какого типа они хранят?

# %%
# загрузим DataSet
try:
    data = pd.read_csv('C:\jubyterbase/moscow_places.csv') 
except:
    data = pd.read_csv('/datasets/moscow_places.csv')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b> Здорово, что есть try-except на этапе загрузки датасета 👍

# %%
data.head()

# %%
# посмотрим из чего состоит DataSet
data.info()

# %% [markdown]
# Вывод:<br>
# - Нам предоставлен DataSet: moscow_places.csv, который назвал data. В data 8 столбцов с информацией. Столбцы: hours, price, avg_bill, middle_avg_bill, middle_coffee_cup, seats имею пропуски. Представлены следующие типы данных: float64(6 столбцов), int64(1 столбцов), object(7 столбцов).<br>
# - Максимальное количество строк: 8406.
# - Пропуски имется в столбцах:<br> hours (536 строк), <br>price (5091 строк), <br>avg_bill (4590 строк),<br> middle_avg_bill (5257 строк), <br>middle_coffee_cup (7871 строк),<br> seats (3611 строк).

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Молодец, что добавляешь краткие выводы после загрузки данных 👍

# %% [markdown]
# # Шаг 2. Выполните предобработку данных

# %% [markdown]
# - Изучите, есть ли дубликаты в данных. Поищите пропуски: встречаются ли они, в каких столбцах? Можно ли их обработать или оставить как есть?<br>
# - Выполните предобработку данных:<br>
# Создайте столбец street с названиями улиц из столбца с адресом.
# Создайте столбец is_24/7 с обозначением, что заведение работает ежедневно и круглосуточно (24/7):<br>
# логическое значение True — если заведение работает ежедневно и круглосуточно;<br>
# логическое значение False — в противоположном случае.

# %%
# поиск дубликатов
data.duplicated().sum()

# %% [markdown]
# Дубликаты отсутствуют

# %%
# посмотрим сколько пропусков в столбцах 
display(data.isna().sum())

# %%
# преобразуем количество мест 'seats' в целочисленное значение (Int64)
data['seats'] = data['seats'].astype('Int64')

# %%
# приведем названия завединий к нижнему регистру
data['name'] = data['name'].str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Молодец, что скорректировал регистр для поиска дубликатов. 👍
#
# ***
#
# Неявные дубликаты могут появиться в случаях, когда данные собирались из разных источников или в системе были какие-то сбои при логировании. Здесь важно учитывать регистр в названиях объектов, в текущем виде неявных дубликатов может не найтись.

# %%
# проверим из чего состоит столбец hours
list(data['hours'].unique())

# %%
# Выполним задание - Создайте столбец street с названиями улиц из столбца с адресом. 
# Создадим отдельный DataSet, где выделим отдельно название улиц
new = data['address'].str.split(",", n = 3, expand = True)  
new

# %%
# запишем в DataSet - data название улиц без указания города, номера дома, корпусов и т.д.
data['street'] = new[1]

# %%
# посмотрим что получилось после добавления столбца 'street'
data.head()

# %%
# Выполним задание - Создайте столбец is_24/7 с обозначением, что заведение работает ежедневно и круглосуточно (24/7)
data['is_24_7'] = data['hours'].str.contains('ежедневно, круглосуточно')

# %%
# в связи с отсутствием информации о часах работы и для удобства дальнейшего изучения удалим пропуски в столбце hours, 
# и соответстветственно в новом столбце is_24_7 
data = data.dropna(subset=['is_24_7', 'hours'])

# %%
# посмотрим что получилось
data

# %%
# убедимся, что в столбце is_24_7 нет ничего лишнего кроме False и True. Пропуски отсутстуют.
data['is_24_7'].unique()

# %%
# Убедимся, что все столбцы имеют нужный тип данных
data.info()

# %% [markdown]
# Вывод:<br>
# В ходе предобработки было сделано следующее:<br>
# 1) Произведён поиск дубликатов. Дубликатов не выявлено;<br>
# 2) Выполнен поиск пропусков. Пропуски имеются в столбцах:<br> hours (536 строк), <br>price (5091 строк), <br>avg_bill (4590 строк),<br> middle_avg_bill (5257 строк), <br>middle_coffee_cup (7871 строк),<br> seats (3611 строк).<br>
# 3) Приведение названий заведений к нижнему регистру;<br>
# 4) Создание столбца street с перенос в него отделённых названий улиц;<br>
# 5) Создание столбца is_24/7 c логическое значение c обозначением True — если заведение работает ежедневно и круглосуточно и False — в противоположном случае.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отлично, все нужные для исследования колонки получены 👍
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# Хорошая работа на данном этапе, но давай немного улучшим. 😊
#
# На шаге предобработки еще стоит:
#
# - Проверить наличие неявных дубликатов - попробуй использовать две колонки (например, `название объекта и адрес заведения`).
#
#     Неявные дубликаты могут появиться в случаях, когда данные собирались из разных источников или в системе были какие-то сбои при логировании. Здесь важно учитывать регистр в названиях объектов, в текущем виде неявных дубликатов может не найтись.
#
# Проверку на неявные дубликаты `лучше проводить после корректировки регистра на нижний`.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# Если есть возможность изучить подробнее:
# 1) Для выявления аномалий в колонке 'name', попробуй еще сгруппировать данные, подсчитать количество значений и отсортировать. Присутсвуют ли заведения с наименованием, которое не совсем информативно?
# Если да, попробуй изучить эти заведения. Стоит ли их оставлять или можно удалить из исследования?
#
# 2) Кроме этого, попробуй рассмотреть пару-тройку популярных названий объектов, нет ли повторов с ошибками в написании? Ниже пример, как можно настроить поиск.
#
# ПРИМЕР РЕВЬЮЕРА
#
#     df[df['name'].str.contains('домино')]['name'].unique()
#
# </div>

# %%
pd.set_option('display.max_rows', None)

# %%
data[['name', 'address']].head()

# %%
#создам отдельный DataSet для поиска неявных дубликатов 
df = data.groupby(['name']) ['address'].unique().reset_index().sort_values(['name'],ascending= True)
df['dup'] = df['address'].duplicated()
df

# %% [markdown]
# Поиск неявных дубликатов в data['name'] выявил следующее:<br>
# яндекс лавка и яндекс.лавка , <br>
# vip wok & sushi и vip wok and sushi,<br>
# пark и паrk фудхолл, <br>
# от и до     от мяса до рыбы<br>

# %%
# заменим их в основном DataSet
data['name'] = data['name'].replace('vip wok & sushi', 'vip wok and sushi')
data['name'] = data['name'].replace('пark', 'паrk фудхолл') 
data['name'] = data['name'].replace('от и до', 'от мяса до рыбы')   
data['name'] = data['name'].replace('яндекс лавка', 'яндекс.лавка')

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> С неявными дубликатами поработал.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №2:</b>
#
# Хорошая работа!
#
# ***
#
# Для поиска неявных дубликатов по колонкам могу рекомендовать такой способ:
#
#     # проверим на "неявные" дубликаты
#     df[['name', 'address']].duplicated().sum()
#
#
#     # выводим "неявные" дубликаты
#     df[df[['name', 'address']].duplicated(keep=False)]
#
#     # удаляем
#     df = df.drop_duplicates(subset=['name', 'address'], keep='last')
#
#
# </div>

# %% [markdown]
# # Шаг 3. Анализ данных

# %% [markdown]
# #### - Какие категории заведений представлены в данных? Исследуйте количество объектов общественного питания по категориям: рестораны, кофейни, пиццерии, бары и так далее. Постройте визуализации. Ответьте на вопрос о распределении заведений по категориям.

# %%
# узнаем какие категорий завадений представлены в данных
list(data['category'].unique())

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# У нас в наличии 8 категорий. Это - 'кафе', 'ресторан', 'пиццерия', 'бар,паб', 'быстрое', 'питание', 'булочная', 'столовая'.

# %%
# узнаем сколько у нас заведений по категориям
category1 = data.pivot_table(index='category',
                                values='address', 
                                aggfunc='count').reset_index().sort_values(['address'],ascending= True )
category1['%'] = (category1['address'] / category1['address'].sum())*100
category1

# %%
# Проверка. Всё верно
category1['address'].sum()

# %%
# визуализируем данные
plt.style.context('seaborn')
fig, ax = plt.subplots(figsize=(14,8))
plt.title('Распределение заведений по категориям')
plt.xlabel('Тип заведения')
plt.ylabel('Количество заведений')
plt.bar(category1['category'],category1['address'])
plt.show()

# %%
# визуализируем соотношение сетевых и несетевых заведений
category = category1['category']
values = category1['%']
fig = go.Figure(data=[go.Pie(labels=category, values=values)])
fig.update_layout(title='Доли типов заведений питания на рынке Москвы', # указываем заголовок графика
                  width=800, # указываем размеры графика
                  height=600,
                  annotations=[dict(x=1.12, # вручную настраиваем аннотацию легенды
                                    y=1.05,
                                    text='Типы заведений',
                                    showarrow=False)])


fig.show()

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# В наличии 8 категорий заведений:<br> кафе - 2003шт.,<br> ресторан - 1969шт.,<br> кофейня - 1398шт.,<br> пиццерия - 628 шт.,<br> бар,паб - 747 шт.,<br> быстрое питание - 570,<br> булочная - 249 шт.,<br> столовая - 306шт. <br>.
# Очень много кафе и ресторанов. Булочных и столовых очень мало. Хороших столовых нахватает  =(

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Определено количество заведений и по типу👍
#
# Молодец, что добавил графикам название и подписи к осям.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# **Комментарий ревьюера  №2**
#
# К сожалению, круговые диаграммы далеко не всегда информативны, т.к. при большом количестве секторов данный вид графика будет сложным к восприятию. Например, может быть сложно сверяться с легендой\цветом и сектором (если говорить про статичный вариант графика).
#
# Круговые графики широко распространены, но и в то же время их часто критикуют и в целом не рекомендуют.
#
# Советую прочесть книгу Богачева **"Графики, которые убеждают всех"**, там много полезного про оптимальную визуализацию (все рекомендации и ссылки оставлю в конце проекта в голубом комментарии)
#
# </div>

# %% [markdown]
# #### - Исследуйте количество посадочных мест в местах по категориям: рестораны, кофейни, пиццерии, бары и так далее. Постройте визуализации. Проанализируйте результаты и сделайте выводы.

# %%
# создадим отдельный DataSet с информацией о категориях и количеством посадочных мест
seats_rest = data[['category', 'seats']]
seats_rest

# %%
# количество категорий 
seats_rest['category'].count()

# %%
# общее известное количество, где указаны посадочные места. Почему-то не все заведения их указали
seats_rest['seats'].count()

# %%
# медианное количество посадочных мест
seats_rest['seats'].median()

# %%
# создаём столбец 'seats_NaN' и присваеваем, где 
# отсутствует информация о посадочных местах - 0. Где есть информация о посадочных местах - 1. 
seats_rest['seats_NaN'] = np.where(seats_rest['seats'].isnull(), 0,1)

# %%
# посмотрим что получилось. Отлично! незаполненные данные в seats = 0, заполненные равны 1.
seats_rest.head()

# %%
# создадим отдельный DataSet c отфильтрованными данными. Умебём пропуски и оставим категории заведений 
# с известными данными по посадочным местам
seats_rest1 = seats_rest.query("`seats_NaN` == 1" ) 
seats_rest1

# %%
# проверка. Всё верно!
seats_rest1['seats'].count()

# %% [markdown]
# У нас имеются данные по 4495 категориям заведений с посадочными местами

# %%
# узнаем по каким категориям у нас есть информация по посадочным местам
seats_rest2 = seats_rest1.pivot_table(index='category',
                                values='seats', 
                                aggfunc='count').reset_index().sort_values(['seats'],ascending= True )
seats_rest2['%'] = (seats_rest2['seats'] / seats_rest2['seats'].sum())*100
seats_rest2

# %%
# проверка. Всё верно!
seats_rest2['seats'].sum()

# %%
# визуализируем данные
plt.style.context('seaborn')
fig, ax = plt.subplots(figsize=(14,8))
plt.title('Количество посадочных мест по категориям (где в DataFrame были указаны посадочные места)')
plt.xlabel('Тип заведения')
plt.xticks(rotation = 30)
plt.ylabel('Количество посадочных мест')
plt.bar(seats_rest2['category'],seats_rest2['seats'])
plt.show()

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Всего заведений с известным количеством посадочных мест: 4495. <br>
# Больше всего мест, конечно, в ресторанах, кафе и кофейнях. Заметно меньше в барах-пабах, пиццериях и в "быстром питании", совсем мало в булочных и стоБольше всего мест, конечно, ловых.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# В данном задании лучше посчитать медианной количество мест по каждой категории (т.к. в колонке есть выбросы)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №2:</b>
#
# Супер 👍
#
# </div>

# %%
# общее известное количество, где указаны посадочные места. Почему-то не все заведения их указали
seats_rest3 = data.groupby('category', as_index=False)['seats'].median().sort_values(['seats'],ascending= True )
seats_rest3.columns = ['category', 'seats']
seats_rest3

# %%
# визуализируем данные
plt.style.context('seaborn')
fig, ax = plt.subplots(figsize=(14,8))
plt.title('Количество посадочных мест по категориям (где в DataFrame были указаны посадочные места)')
plt.xlabel('Тип заведения')
plt.xticks(rotation = 30)
plt.ylabel('Количество посадочных мест')
plt.bar(seats_rest3['category'],seats_rest3['seats'])
plt.show()

# %% [markdown]
# #### - Рассмотрите и изобразите соотношение сетевых и несетевых заведений в датасете. Каких заведений больше?

# %%
# создадим DataSet с информацией о сетевых и несетевых заведениях 
chain_0_1 = data.groupby('chain', as_index=False)['category'].count()
chain_0_1['ratio%'] = (chain_0_1['category'] / chain_0_1['category'].sum())*100
chain_0_1

# %%
# визуализируем соотношение сетевых и несетевых заведений
category = chain_0_1['chain']
values = chain_0_1['ratio%']
fig = go.Figure(data=[go.Pie(labels=category, values=values)])
fig.update_layout(title='Доли типов заведений питания на рынке Москвы', # указываем заголовок графика
                  width=800, # указываем размеры графика
                  height=600,
                  annotations=[dict(x=1.12, # вручную настраиваем аннотацию легенды
                                    y=1.05,
                                    text='Типы заведений, 0 — заведение не является сетевым 1 — заведение является сетевым',
                                    showarrow=False)])


fig.show()

# %%
# создадим DataSet с информацией о сетивых и несетевых заведениях
set = data[['chain']]
set.head()

# %%
# несетевые заведения
set_0 = set.query("`chain` == 0" )
set_0['chain'].count()

# %% [markdown]
# Несетевых заведений - 4781

# %%
# сетевые заведения
set_1 = set.query("`chain` == 1" )
set_1['chain'].count()

# %% [markdown]
# Сетевых заведений - 3089

# %%
# проверка. Всё верно! 
data['name'].count()

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Всего сетевых и не сетевых заведений: 7870<br>
# Сетевых заведений - 3089<br>
# Несетевых заведений - 4781<br>
#
# Соответственно несетевых заведений больше.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера**
#
# Все верно 👍 Молодец, что заменил 0 и 1 на более оптимальный и понятный вариант обозначения.

# %% [markdown]
# #### - Какие категории заведений чаще являются <b>сетевыми</b>? Исследуйте данные и ответьте на вопрос графиком.<br>
#
# chain — число, выраженное 0 или 1, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):<br> 0 — заведение не является сетевым<br> 1 — заведение является сетевым

# %%
# создадим DataSet с информацией про категории заведений и срезом информации о сетевых заведениях
cat_set = data[['category', 'chain']].query("`chain` == 1" ).pivot_table(index='category',
                                values='chain', 
                                aggfunc='sum').reset_index().sort_values(['chain'],ascending= False )
cat_set['%'] = (cat_set['chain'] / cat_set['chain'].sum())*100
cat_set

# %%
# проверка
cat_set['chain'].sum()

# %%
# визуализируем данные
plt.style.context('seaborn')
fig, ax = plt.subplots(figsize=(14,8))
plt.title('Количество заведений, которые чаще всего являются сетевыми')
plt.xlabel('Тип заведения')
plt.xticks(rotation = 30)
plt.ylabel('Количество заведений')
plt.bar(cat_set['category'],cat_set['chain'])
plt.show()

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Всего сетевых заведений: 3089<br>
# С разбивкой по категориям:<br>
# кофейня - 714<br>
# ресторан - 712<br>
# кафе - 711<br>
# пиццерия - 330<br>
# быстрое питание - 224<br>
# бар,паб - 159<br>
# булочная - 154<br>
# столовая - 85<br>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# Немного нужно доработать вопрос **Рассмотрите и изобразите соотношение сетевых и несетевых заведений в датасете. Каких заведений больше?**
#
# Ты в целом верно сделал расчеты и построил хороший график, но давай посмотрим не на абсолютные значения, а на доли (**в рамках одной категории**). Например, % сетевых ресторанов от всех ресторанов.
#
# PS - после внесения изменений нужно будет скорректировать вывод.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> То есть нужно провести дополнительное исследование по соотношению сетевых и не сетевых? я верно понял? (задаю вопрос заранее зная, что уйду на вторую доработку)))) 😅😧 </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера №2:</b>
#
# 😅
#
# Тут все не так сложно, как кажется)))
#
# Тебе нужно посчитать долю сетевых заведений в рамках одной категории (потому что, если взять все, то будут лидировать самые многочисленные).
#
# Например, можно создать такую таблицу, куда добавляешь колонку ratio:
#
#     df_grouped_category =  (data.groupby('category', as_index=False)
#                               .agg(count_object=('name', 'count'))
#                               .sort_values(by='count_object', ascending=False))
#     df_grouped_category['ratio'] = df_grouped_category['count_object'] / df_grouped_category['count_object'].sum()
#     df_grouped_categoryy
#
#     ***
#
#     df_chain =  (data.query('chain == 1').groupby('category', as_index=False)
#                               .agg(count_object=('name', 'count')))
#     df_chain['ratio'] = round(df_chain['count_object'] / df_grouped_category['count_object'], 3)
#     df_chain = df_chain.sort_values(by='ratio', ascending=False)
#     df_chain
#
#
# И дальше посмотртеть, у каких категорий наибольшая доля =)
#
# **PS - этот комментарий немного дополнила на итерации 3**
#
# </div>

# %%
# Пример 1
df_grouped_category =  (data.groupby('category', as_index=False)
                              .agg(count_object=('name', 'count'))
                              .sort_values(by='count_object', ascending=False))
df_grouped_category['ratio'] = df_grouped_category['count_object'] / df_grouped_category['count_object'].sum()

# %%
df_chain =  (data.query('chain == 1').groupby('category', as_index=False)
                              .agg(count_object=('name', 'count')))
df_chain['ratio'] = round(df_chain['count_object'] / df_grouped_category['count_object'], 3)*100
df_chain = df_chain.sort_values(by='ratio', ascending=False)
df_chain

# %%
#проверка
#data_chain['ratio'].sum()

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Доля сетевых кофеен в лидерах! В "спину" кофеням дышат рестораны. А в "спину" ресторанам кафе! Тройка лидеров: кофейни, рестораны и кафе! Далее из сетевых по низходящей: пиццерии (кто туда сейчас ходит? доставка рулит!), быстрое питание, ,бар-паб, булочная, столовая </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №3:</b>
#
# Здесь давай немного помогу, еще один пример (но уже с pivot_table) ниже в коде. И выше немного дополнила.
#
# Итого - булочные чаще всего являются сетевыми объектами - 61.8% (в рамках одной категории). По количеству объектов булочные немногочисленная категория, но если сравнивать в абсолютных значениях, то будут лидировать те категории, у кого больше объектов.
#
# ***
#
#     #проверка
#     data_chain['ratio'].sum()
#
# Эта часть уже не нужна, потому что смотрим не от общего числа, а в рамках одной категории
#
# </div>

# %%
# Код ревьюера (пример 2)
data_chain = data.pivot_table(index='category', columns= 'chain', values='name', aggfunc='count')

data_chain.columns = ['no_chain', 'chain']
data_chain['ratio']= round(data_chain['chain']*100/(data_chain['chain'] + data_chain['no_chain']), 2)
data_chain.sort_values(by='ratio', ascending = False)

# %% [markdown]
# #### - Сгруппируйте данные по названиям заведений и найдите топ-15 популярных сетей в Москве. Под популярностью понимается количество заведений этой сети в регионе. Постройте подходящую для такой информации визуализацию. Знакомы ли вам эти сети? Есть ли какой-то признак, который их объединяет? К какой категории заведений они относятся?

# %%
# согдадим DataSet с информацмей 
# name_top15 = data[['name']]
# name_top15

# %%
# сгруппируем данные по названиям популярных сетевых заведений
popular_establishments=data.loc[data['chain'] == 1].groupby('name', as_index=False)['rating'].count()
# присвоим названия столбцов в переменной
popular_establishments.columns = ['name', 'quantity']
# отсортируем 
popular_establishments = popular_establishments.sort_values(by='quantity', ascending=False)
pop = popular_establishments.head(15)
pop

# %%
# визуализируем данные
plt.style.context('seaborn')
fig, ax = plt.subplots(figsize=(14,8))
plt.title('Количество заведений, которые чаще всего являются сетевыми')
plt.xlabel('Тип заведения')
plt.xticks(rotation = 30)
plt.ylabel('Количество заведений')
plt.bar(pop['name'], pop['quantity'])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,8))
ax = sns.barplot(y ='name', x='quantity', data= pop)
ax.set_ylabel('Сети топ-15')
ax.set_xlabel('количество объектов')
ax.set_title('Наиболее популярные сетевые заведения', fontsize = 15)

plt.show()

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Из представленных заведений больше всего сетевых: <br>
# <b>шоколадница</b> - 120 заведений; <br>
#
# Меньше всего сетевых заведений:<br>
# <b>му-му</b>  - 27 заведений<br>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Все названия сетей на слуху👍
#
# Аккуратные графики, хорошо, что есть название и подписи к осям
#
# </div>

# %% [markdown]
# #### - Какие административные районы Москвы присутствуют в датасете? Отобразите общее количество заведений и количество заведений каждой категории по районам. Попробуйте проиллюстрировать эту информацию одним графиком.

# %%
# согдадим DataSet с информацией об администранивных округах и категориях заведений
adm_terr = data[['district', 'category']]
adm_terr.head()

# %%
# проверка! 
adm_terr.agg({'category': ['count']})

# %%
# подсчитаем сколько категорий заведений с разбивкой по округам
adm_terr1 = data.pivot_table(index='district',
                                     values='name',
                                     columns='category',
                                     aggfunc='count').reset_index().sort_values(['district'],ascending= True)
adm_terr1

# %%
# визуализация
adm_terr1.plot(x="district", kind='barh', stacked=True, figsize=(15,10))
plt.title('Количество заведений с разбивкой по округам')
plt.xlabel('Количество заведений')
plt.ylabel('Название округов')

# %%
# подсчитаем сколько категорий заведений с разбивкой по округам с обобщением
adm_terr1['общее']=adm_terr1.loc[:, 'бар,паб':'столовая'].sum(axis=1)
adm_terr1

# %%
# проверка! верно!
adm_terr1['общее'].sum()

# %%
# визуализация
adm_terr1.plot(x="district", kind='barh', stacked=True, figsize=(15,10))
plt.title('Количество заведений с разбивкой по округам')
plt.xlabel('Количество заведений')
plt.ylabel('Название округов')

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Больше всего заведений в ЦАО;<br>
# Меньше всего в СЗАО<br>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Хорошая проработка задания👍
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# Для улeчшения визуальной составляющей, график можно сделать инструментами билиотеки `plotly.express.bar`
#
# Хорошие примеры можно посмотреть тут:
#
# - https://plotly.com/python/bar-charts/
# - https://plotly.com/python/horizontal-bar-charts/
# - https://plotly.com/python-api-reference/generated/plotly.express.bar.html (и документация)
#
# </div>

# %% [markdown]
# #### - Визуализируйте распределение средних рейтингов по категориям заведений. Сильно ли различаются усреднённые рейтинги в разных типах общепита?

# %%
# выясним средний рейтинг по заведениям
category_rating= data[['category', 'rating']]
category_rating1 = category_rating.groupby('category').mean().reset_index().sort_values(['rating'],ascending= True )
category_rating1

# %%
# поправить график, чтобы было яснее 
plt.style.context('seaborn')
fig, ax = plt.subplots(figsize=(10,4))
plt.title('Визуализация распределение средних рейтингов по категориям заведений')
plt.xlabel('Тип заведения')
plt.xticks(rotation = 30)
plt.ylabel('Средний рейтинг заведений')
plt.bar(category_rating1['category'], category_rating1['rating'])
plt.show()

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Средний рейтинг всех заведений одинаково высокий. Свыше 4 баллов из 5. Средний рейтинг на общую картину не влияет.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Правильно, что используешь mean(), брать медиану по фиксированным значениями от 1 до 5 - не совсем целесообразно.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# График неплохой, но стоит добавить детализации, потому что сейчас считать рейтинг каждой категории сложно.😅
#
# Для улучшения визуальной составляющей можно (варианты):
#
# 1. Нанести обозначения (рейтинг) на текущий график
#
# 2. Сделать инструментами билиотеки `plotly.express.bar`:
# - https://plotly.com/python/bar-charts/
# - https://plotly.com/python/horizontal-bar-charts/
# - https://plotly.com/python-api-reference/generated/plotly.express.bar.html (и документация)
#
# </div>

# %%
# построим график средних рейтингов по категориям заведений
plt.style.use('seaborn')
plt.bar(category_rating1['category'], category_rating1['rating'])
plt.xlabel("Тип заведения")
plt.ylabel("Внличина среднего рейтинга")
plt.title("Средние рейтинги заведений по категориям")
plt.ylim((3.5, 4.5))
plt.show()

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Такую штуку осилил)</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №2:</b>
#
# Стало более наглядно👍
#
# </div>

# %% [markdown]
# #### - Постройте фоновую картограмму (хороплет) со средним рейтингом заведений каждого района. Границы районов Москвы, которые встречаются в датасете, хранятся в файле admin_level_geomap.geojson (скачать файл для локальной работы).

# %% [markdown]
# Отобразите все заведения датасета на карте с помощью кластеров средствами библиотеки folium.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# В этой части пропущено задание: ** Постройте фоновую картограмму (хороплет) со средним рейтингом заведений каждого района. Границы районов Москвы, которые встречаются в датасете, хранятся в файле admin_level_geomap.geojson.**
#
#
# Требуется сделать холопрет со средними рейтингами по районам =)
#
# </div>

# %%
rating_df = data.groupby('district', as_index=False)['rating'].agg('mean')
rating_df

# %%
# импортируем карту и хороплет
from folium import Map, Choropleth

# загружаем JSON-файл с границами округов Москвы
state_geo = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=rating_df,
    columns=['district', 'rating'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Медианный рейтинг заведений по районам',
).add_to(m)

# выводим карту
m

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Есть!</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №2:</b>
#
# Отличный холопрет!🔥
#
# </div>

# %%
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
data.apply(create_clusters, axis=1)

# выводим карту
m

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Коментарий ревьюера:</b>
#
# Хорошая карта 😊
#
# </div>

# %% [markdown]
# #### - Найдите топ-15 улиц по количеству заведений. Постройте график распределения количества заведений и их категорий по этим улицам. Попробуйте проиллюстрировать эту информацию одним графиком.

# %%
# Найдите топ-15 улиц по количеству заведений.
top15_street_2 = data.pivot_table(index='street', values='name', columns='category', aggfunc='count').reset_index()

top15_street_2

# %%
# Найдите топ-15 улиц по количеству заведений с обобщением
top15_street_2['общее']=top15_street_2.loc[:, 'бар,паб':'столовая'].sum(axis=1)
top15_street_3 = top15_street_2.sort_values(['общее'],ascending= False).head(15)
top15_street_3

# %%
# Постройте график распределения количества заведений и их категорий по этим улицам.
top15_street_3.plot(x="street", kind='barh', stacked=True, figsize=(15,10))
plt.title('Найдите топ-15 улиц по количеству заведений')
plt.xlabel('Количество заведений')
plt.ylabel('Названия улиц')

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Больше всего заведений на проспекте Мира;<br>
# Меньше всего на ул. Миклухо-Маклая

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Молодец 👍 Все верно по заданию.

# %% [markdown]
# #### - Найдите улицы, на которых находится только один объект общепита. Что можно сказать об этих заведениях?

# %%
# Создадим DataSet с информацией об улицах и категориям заведений
object_2_street = data.groupby(['category', 'street'])['name'].count().reset_index().query("`name` == 1" )
object_2_street

# %%
# Создадим DataSet с информацией об улицах и категориям заведений, на улицах которых находится одно заведение
object_3_street = object_2_street.pivot_table(index='category',
                                              values='name',
                                              aggfunc='sum').reset_index().sort_values(['name'],ascending= False)
object_3_street

# %%
# визуализируем данные
plt.style.context('seaborn')
fig, ax = plt.subplots(figsize=(14,8))
plt.title('Количество улиц, на которых находится только один тип объекта общепита')
plt.xlabel('Тип заведения')
plt.xticks(rotation = 30)
plt.ylabel('Количество улиц')
plt.bar(object_3_street['category'],object_3_street['name'])
plt.show()

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Категория заведений "кафе" - лидер среди улиц, где других типов заведений нет;<br>
# Категория заведений "булочная" - меньше всего улиц, где других типов заведений нет;

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# Лучше сгруппировать без добавления категорий (посмотреть сколько всего улиц с одним объектом)
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера #2:</b>
#
# Это задание, кажется, еще не доработано?
#
# Вот здесь стоит убрать категории 'category':
#
#     object_2_street = data.groupby(['category', 'street'])['name'].count().reset_index().query("`name` == 1" )
#
# И потом посчитать, сколько получилось улиц с одним объектом.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Блин! Наверное не заметил. А скорее забыл.</div>

# %%
object_4_street = data.groupby(['street'])['name'].count().reset_index().query("`name` == 1" )
object_4_street

# %%
object_4_street['street'].count()

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №3:</b>
#
# Молодец 👍 Все верно.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Получается 471 улица с одним объектом</div>

# %% [markdown]
# #### - Значения средних чеков заведений хранятся в столбце middle_avg_bill. Эти числа показывают примерную стоимость заказа в рублях, которая чаще всего выражена диапазоном. Посчитайте медиану этого столбца для каждого района. Используйте это значение в качестве ценового индикатора района. Постройте фоновую картограмму (хороплет) с полученными значениями для каждого района. Проанализируйте цены в центральном административном округе и других. Как удалённость от центра влияет на цены в заведениях?

# %%
# медиана цена среднего чека по заведениям
data['middle_avg_bill'].median()

# %%
# подгтовим информацию для визуализации
rating_df = data.groupby('district', as_index=False)['middle_avg_bill'].agg('median').sort_values(['middle_avg_bill'],ascending= True )
rating_df

# %% [markdown]
# <u>Промежуточный вывод:</u> <br>
# Минимальный средний чек в заведениях ЮВАО - 450 рублей;<br>
# Максимальный средний чек в заведениях ЗАО и ЦАО - 1000 рублей;<br>

# %%
# импортируем карту и хороплет
from folium import Map, Choropleth

# загружаем JSON-файл с границами округов Москвы
state_geo = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=rating_df,
    columns=['district', 'middle_avg_bill'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Медианный рейтинг заведений по районам',
).add_to(m)

# выводим карту
m

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: </b>
#
# Молодец, что берешь именно медианную оценку  👍
#
# Красивая, интераткивная карта!
#
# </div>

# %% [markdown]
# <u>Общий вывод шага №3:</u> <br>
#
# 1) У нас в наличии 8 категорий. Это - 'кафе', 'ресторан', 'пиццерия', 'бар,паб', 'быстрое', 'питание', 'булочная', 'столовая'.
#
# 2) В наличии 8 категорий заведений:
# кафе - 2003шт.,
# ресторан - 1969шт.,
# кофейня - 1398шт.,
# пиццерия - 628 шт.,
# бар,паб - 747 шт.,
# быстрое питание - 570,
# булочная - 249 шт.,
# столовая - 306шт.
# . Очень много кафе и ресторанов. Булочных и столовых очень мало. Хороших столовых нахватает  =(
#
# 3) Всего заведений с известным количеством посадочных мест: 4495.
# Больше всего мест конечно в ресторанах, кафе и кофейнях. Заметно меньше в барах-пабах, пиццериях и в "быстром питании", совсем мало в булочных и столовых.
#
# 4) Всего сетевых и не сетевых заведений: 7870
# Сетевых заведений - 3089
# Несетевых заведений - 4781
#
#
# 5) Всего сетевых заведений: 3089
# С разбивкой по категориям:
# кофейня - 714
# ресторан - 712
# кафе - 711
# пиццерия - 330
# быстрое питание - 224
# бар,паб - 159
# булочная - 154
# столовая - 85
#
#
# 6) Из представленных заведений больше всего сетевых:
# шоколадница - 120 заведений;
#
# Меньше всего сетевых заведений:
# му-му - 27 заведений
#
#
# 7) Больше всего заведений в ЦАО;
# Меньше всего в СЗАО
#
#
# 8) Средний рейтинг всех заведений одинаково высокий. Свыше 4 баллов из 5. Средний рейтинг на общую картину не влияет.
#
#
# 9) Больше всего заведений на проспекте Мира;
# Меньше всего на ул. Миклухо-Маклая
#
#
# 10) Категория заведений "кафе" - лидер среди улиц, где других типов заведений нет;
# Категория заведений "булочная" - меньше всего улиц, где других типов заведений нет;

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Подробный вывод по разделу 🔥

# %% [markdown]
# # Шаг 4. Детализируем исследование: открытие кофейни

# %% [markdown]
# Основателям фонда «Shut Up and Take My Money» не даёт покоя успех сериала «Друзья». Их мечта — открыть такую же крутую и доступную, как «Central Perk», кофейню в Москве. Будем считать, что заказчики не боятся конкуренции в этой сфере, ведь кофеен в больших городах уже достаточно. Попробуйте определить, осуществима ли мечта клиентов.

# %% [markdown]
# - Сколько всего кофеен в датасете? В каких районах их больше всего, каковы особенности их расположения?
# - Есть ли круглосуточные кофейни?
# - Какие у кофеен рейтинги? Как они распределяются по районам?
# - На какую стоимость чашки капучино стоит ориентироваться при открытии и почему?

# %% [markdown]
# #### - Сколько всего кофеен в датасете? В каких районах их больше всего, каковы особенности их расположения?

# %%
coffee_house = data[['name', 'category', 'district', 'street', 'lat', 'lng']].query("`category` == 'кофейня'" )
coffee_house

# %%
display(coffee_house['category'].count())

# %% [markdown]
# В DataSet 1398 кофеен.

# %%
coffee_house1 = coffee_house.pivot_table(index='district',
                                     values='street',
                                     columns='category',
                                     aggfunc='count').reset_index().sort_values(['кофейня'],ascending= False )
coffee_house1

# %%
display(coffee_house1['кофейня'].sum()) # проверка

# %% [markdown]
# Значительно больше всего кофейен в ЦАО - 426 шт. Потом идут в порядке убывания: САО, СВАО, ЗАО, ЮАО, ВАО, ЮЗАО, ЮВАО, СЗАО

# %% [markdown]
# В датасете 1398 кофеен

# %%
coffee_house1.plot(x="district", kind='barh', stacked=False, figsize=(15,10))
plt.title('Количество кофеен с разбивкой по округам')
plt.xlabel('Количество кофеен')
plt.ylabel('Название округов')

# %% [markdown]
# <u>Промежуточный ответ:</u> <br>
# Всего в нашем DataSet представлено 1398 кофейен <br>
# Больше всего кофеен в ЦАО;<br>
# Меньше всего в СЗАО

# %%
# покажим на кагре где у нас кофейни
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['category']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
coffee_house.apply(create_clusters, axis=1)

# выводим карту
m

# %% [markdown]
# #### - Есть ли круглосуточные кофейни?

# %%
coffee_house_24_1 = data[['name', 'category','hours', 'district', 'street', 'lat', 'lng']].query("`category` == 'кофейня'" )

coffee_house_24_1['is_24'] = coffee_house_24_1['hours'].str.contains('круглосуточно')
coffee_house_24_1.groupby(['is_24']) ['category'].count()
coffee_house_24_2 = coffee_house_24_1.query("`is_24` == True" )
coffee_house_24_2

# %%
coffee_house_24 = data[['category','hours']].query("`category` == 'кофейня'" )
coffee_house_24['is_24'] = coffee_house_24['hours'].str.contains('круглосуточно')
coffee_house_24_1 = coffee_house_24.groupby(['is_24']) ['category'].count().reset_index()
coffee_house_24_1

# %% [markdown]
# Круглосуточных кофейей всего 76 шт.
# Основное количество кофейен некруглосуточные. Их 1322 шт.

# %%
# покажим на кагре где у нас кофейни работающие круглосуточно
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['category']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
coffee_house_24_2.apply(create_clusters, axis=1)

# выводим карту
m

# %%
# подготовим данные для визуализации. Круглосуточные кофейни
coffee_house_24_2
coffee_house_24_5 = coffee_house_24_2.groupby(['district']) ['name'].count().reset_index().sort_values(['name'],ascending= False )
coffee_house_24_5

# %%
# импортируем карту и хороплет по круглосуточным кофейням по округам
from folium import Map, Choropleth

# загружаем JSON-файл с границами округов Москвы
state_geo = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=coffee_house_24_5,
    columns=['district', 'name'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Количество круглосуточный кофеен в Москве',
).add_to(m)

# выводим карту
m

# %% [markdown]
# <u>Промежуточный ответ:</u> <br>
# Круглосуточных кафе всего 76.

# %% [markdown]
# #### - Какие у кофеен рейтинги? Как они распределяются по районам?

# %%
coffee_house_rating_district = data[['name', 'category','hours', 'district', 'street','rating' , 'lat', 'lng']].query("`category` == 'кофейня'" )
coffee_house_rating_district

# %% [markdown]
# Лучший заведений с рейтингом 5.0 :

# %%
# подготовка данных для карты и хороплета для рейтинга кофеен 5.0
coffee_house_rating_district3 = coffee_house_rating_district.query("`rating` == 5.0" ).groupby(['district']) ['name'].count().reset_index().sort_values(['name'],ascending= False )
coffee_house_rating_district3

# %%
# подсчёт кофеен с рейтингом 5.0
coffee_house_rating_district3 ['name'].sum()

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Интересный подход🔥
#
# </div>

# %%
# импортируем карту и хороплет по круглосуточным кофейням по округам
from folium import Map, Choropleth

# загружаем JSON-файл с границами округов Москвы
state_geo = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=coffee_house_rating_district3 ,
    columns=['district', 'name'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Количество кофеен с рейтиноом 5.0 в Москве',
).add_to(m)

# выводим карту
m

# %% [markdown]
# Рейтинг кофеен со среднем рейтингом от 3 до 4.9:

# %%
# подготовка данных для карты и хороплета для рейтинга кофеен от 3.0 до 4.9
coffee_house_rating_district_3_4_1 =  coffee_house_rating_district.query("`rating` >= 3.0 & `rating` <= 4.9" ) .groupby(['district']) ['name'].count().reset_index().sort_values(['name'],ascending= False )
coffee_house_rating_district_3_4_1

# %%
coffee_house_rating_district_3_4_1['name'].sum()

# %%
# импортируем карту и хороплет для рейтинга кофеен от 3.0 до 4.9
from folium import Map, Choropleth

# загружаем JSON-файл с границами округов Москвы
state_geo = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=coffee_house_rating_district_3_4_1 ,
    columns=['district', 'name'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Количество круглосуточный кофеен в Москве',
).add_to(m)

# выводим карту
m

# %% [markdown]
# Рейтинг кофеен с низким рейтингом: 0 до 2.9

# %%
# подготовка данных для карты и хороплета для рейтинга кофеен от 0.0 до 2.9
coffee_house_rating_district_0_1_1 =  coffee_house_rating_district.query("`rating` >= 0.0 & `rating` <= 2.9" ) .groupby(['district']) ['name'].count().reset_index().sort_values(['name'],ascending= False )
coffee_house_rating_district_0_1_1

# %%
coffee_house_rating_district_0_1_1['name'].sum()

# %%
# импортируем карту и хороплет для рейтинга кофеен от 0.0 до 2.9
from folium import Map, Choropleth

# загружаем JSON-файл с границами округов Москвы
state_geo = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=coffee_house_rating_district_0_1_1 ,
    columns=['district', 'name'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Количество круглосуточный кофеен в Москве',
).add_to(m)

# выводим карту
m

# %%
# подготовим данные для визуализации карты и хороплета среднего рейтинга по округам
coffee_house_rating_district1 = coffee_house_rating_district.groupby('district').mean().reset_index().sort_values(['rating'],ascending= True )
coffee_house_rating_district1

# %%
# импортируем карту и хороплет по среднему рейтингу по округам
from folium import Map, Choropleth

# загружаем JSON-файл с границами округов Москвы
state_geo = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=coffee_house_rating_district1,
    columns=['district', 'rating'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Медианный рейтинг заведений по районам',
).add_to(m)

# выводим карту
m

# %% [markdown]
# #### - На какую стоимость чашки капучино стоит ориентироваться при открытии и почему?

# %%
cappuccino_price = data[['name','district', 'category', 'middle_coffee_cup','lat', 'lng']].query("`category` == 'кофейня'" ).dropna(subset=['middle_coffee_cup']) 
cappuccino_price

# %%
cappuccino_price['middle_coffee_cup'].median()

# %% [markdown]
# Медианная стоимость чашки капучино по всему городу: 169.5 рублей.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №2:</b>
#
# Молодец, что рассматриваешь медианную оценку
#
# </div>

# %%
# подготовим данные для визуализации карты и хороплета по средней стоимости капучино по округам
cappuccino_price1 = data[['category','district', 'middle_coffee_cup' , 'lat', 'lng']].query("`category` == 'кофейня'" )
cappuccino_price2 = cappuccino_price1.groupby('district').median().reset_index().sort_values(['middle_coffee_cup'],ascending= True )
cappuccino_price2

# %%
# подготовим данные для постироения графика средней стоимости капучино по округам 
cappuccino_price4 = cappuccino_price2[['district', 'middle_coffee_cup']]

# %%
# визуализируем данные средней стоимости капучино по округам 
cappuccino_price4.plot(x="district", kind='barh', stacked=False, figsize=(15,10))
plt.title('Средняя цена чашки капучино с разбивкой по округам')
plt.xlabel('Средняя цена капучино')
plt.ylabel('Название округов')

# %% [markdown]
# Самая высокая средняя стоимость капучино в ЮЗАО;<br>
# Самая низкая стоимость в ВАО

# %%
# покажим на кагре конейни со средней стоимостью капучино
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['middle_coffee_cup']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
cappuccino_price.apply(create_clusters, axis=1)

# выводим карту
m

# %%
# импортируем карту и хороплет
from folium import Map, Choropleth

# загружаем JSON-файл с границами округов Москвы
state_geo = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=cappuccino_price2,
    columns=['district', 'middle_coffee_cup'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Медианный стоимость капучино по районам',
).add_to(m)

# выводим карту
m

# %% [markdown]
# Промежуточный вывод:<br>
# Исходя из проведённого выше анализа стоит обратить внимания на ЮЗАО и ЗАО исключив ЦАО. В ЦАО много кофетерий, а соответственно большая конкуренция. В <b>ЮЗАО (цена чашки 198 рублей) и ЗАО (цена чашки 189 рубля)</b> .<br>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера №2:</b>
#
# Здорово, что добавляешь промежуточные выводы!
#
# </div>

# %% [markdown]
# - Изучим информацию о кофейнях в ЗАО

# %%
# отфильтруем данные
coffi_zao = data.query("`district` == 'Западный административный округ'" ).head()  #

# %%
# срез по средниму чеку в кофетерии
data.loc[data['district'] == 'Западный административный округ'].groupby('category')['middle_avg_bill'].describe().query("`category` == 'кофейня'" )

# %%
# срез по средниму чеку за капучино в кофетерии
data.loc[data['district'] == 'Западный административный округ'].groupby('category')['middle_coffee_cup'].describe().query("`category` == 'кофейня'" )

# %% [markdown]
# - Промежуточный вывод:<br>
#
# По ЗАО всего 18 кофеен, где имеется информация по среднему чеку.<br>
# 25% - 400 рублей;<br>
# 50% - 600 рублей;<br>
# 75% - 850 рублей;<br>
# Средний чек: 694.44 рубль;<br><br>
#
# По ЗАО всего 49 кофеени, где имеется информация по среднему чеку за чашейчку капучино.<br>
# 25% - 130 рублей;<br>
# 50% - 189 рублей;<br>
# 75% - 256 рублей;<br>
# Средний чек за чашку: 189.93 рубль;<br><br>

# %% [markdown]
# - Изучим информацию о кофейнях в ЮЗАО

# %%
# отфильтруем данные
coffi_uzao = data.query("`district` == 'Юго-Западный административный округ'" ).head()  #

# %%
# описание статистики по среднему чеку в кофейнях ЮЗАО
data.loc[data['district'] == 'Юго-Западный административный округ'].groupby('category')['middle_avg_bill'].describe().query("`category` == 'кофейня'" )

# %%
# описание статистики по стоимости чашки капучино в кофейнях ЮЗАО
data.loc[data['district'] == 'Юго-Западный административный округ'].groupby('category')['middle_coffee_cup'].describe().query("`category` == 'кофейня'" )

# %% [markdown]
# - Промежуточный вывод:<br>
#
# По ЮЗАО всего 11 кофеен, где имеется информация по среднему чеку.<br>
# 25% - 275 рублей;<br>
# 50% - 275 рублей;<br>
# 75% - 400 рублей;<br>
# Средний чек: 381.81 рубль;<br><br>
#
# По ЮЗАО всего 34 кофеени, где имеется информация по среднему чеку за чашейчку капучино.<br>
# 25% - 129 рублей;<br>
# 50% - 198 рублей;<br>
# 75% - 229.25 рублей;<br>
# Средний чек за чашку: 184.18 рубль;<br><br>

# %% [markdown]
# Вывод:<br>
# В ЗАО в кофейнях средний чек: 694.44 рубль; Средний чек за чашку: 189.93 рубль; <br>
# В ЮЗАО в кофейнях средний чек: 381.81 рубль; Средний чек за чашку: 184.18 рубль
#
# Обратив своё внимание на конейнм <b>ЗАО</b>, т.к. там средний чек в кафе и средняя цена чашки выше, чем в <b>ЮЗАО</b>.

# %%
# срез с информацией. где находится всего однна кофейня конкурентов
street_zao = data.loc[data['district'] == 'Западный административный округ'].query("`category` == 'кофейня'" ) 
street_zao.head()

# %%
# покажим на кагре конейни со средней стоимостью капучино
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['middle_coffee_cup']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
street_zao.apply(create_clusters, axis=1)

# выводим карту
m

# %%
# рекоменованные улицы, на которые необходимо обратить внимание при открытии кафе в стиле "central perk" из сериала Друзья
street_zao1 = street_zao.groupby('street')['name'].count().reset_index().sort_values(['name'],ascending= False ).query("`name` == 1" ) 
street_zao1

# %%
# в ЗАО 29 улиц, где один кофетерий
street_zao1['street'].count()

# %% [markdown]
# 29 улиц с одниой кофейней

# %% [markdown]
# Вывод шага №4:<br>
#
# 1) Круглосуточных кофейей всего 76 шт. Основное количество кофейен некруглосуточные. Их 1322 шт.<br>
#
# 2) Исходя из проведённого выше анализа стоит обратить внимания на ЮЗАО и ЗАО исключив ЦАО. В ЦАО много кофетерий, а соответственно большая конкуренция. В ЮЗАО (цена чашки 198 рублей) и ЗАО (цена чашки 189 рубля) .<br>
#
# 3)
# По ЗАО всего 18 кофеен, где имеется информация по среднему чеку.<br>
# 25% - 400 рублей;<br>
# 50% - 600 рублей;<br>
# 75% - 850 рублей;<br>
# Средний чек: 694.44 рубль;<br>
#
# По ЗАО всего 49 кофеен, где имеется информация по среднему чеку за чашечку  капучино.<br>
# 25% - 130 рублей;<br>
# 50% - 189 рублей;<br>
# 75% - 256 рублей;<br>
# Средний чек за чашку: 189.93 рубль;<br>
#
#
# По ЮЗАО всего 11 кофеен, где имеется информация по среднему чеку.<br>
# 25% - 275 рублей;<br>
# 50% - 275 рублей;<br>
# 75% - 400 рублей;<br>
# Средний чек: 381.81 рубль;<br>
#
#
# По ЮЗАО всего 34 кофеен, где имеется информация по среднему чеку за чашечку  капучино.<br>
# 25% - 129 рублей;<br>
# 50% - 198 рублей;<br>
# 75% - 229.25 рублей;<br>
# Средний чек за чашку: 184.18 рубль;<br>
#
# 4) 471 улиц с одниой кофейней

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: </b>
#
# Василий, ты провел подробное исследование по датасету и кофейням👍
#
# Молодец, что дал подробные рекомендации, относительно места открытия 🔥
#
# </div>

# %% [markdown]
# # Рекомендации для выбора места для открытия кафе

# %% [markdown]
# На основании анализа улиц, где расположена лишь одна кофейня рекомендую обратить внимание на <b>улицу Никулинскую</b> в районе пересечения с Мичуринским проспектом, расположенную рядом со станцией метро Озёрная. Рядом с метро Озёрная расположен крупный жилищный массив, а также большой количество офисных, а также производственных помещений. В связи с нехваткой приятных и уютных мест встречи и приятного времяпрепровождения за чашечкой капучино мест рекомендую рассмотреть следующие точки размещения нашего кофетерия:

# %% [markdown]
# 1) ТРЦ Мичурниский;<br>
# 2) Нежилые помещения 1-х этаже многоквартирных домов по адресам: Никулинская улица, д.27 к.1, Никулинская улица, д.27 к.2, Никулинская улица, д.27 к.3;<br>
# 3) ТЦ у метро Озёрная (3-й выход)

# %%
# подключаем библиотеку
import folium      

# сохраняем координаты ТРЦ Мичуринский  в переменные
mishorinski_lat, mishorinski_lng = 55.671918, 37.446122
# сохраняем координаты жилого дома по адресу: Никулинская улица, д.27 к.1 в переменные
dom27_1_lat, dom27_1_lng = 55.669999, 37.452043
# сохраняем координаты жилого дома по адресу: Никулинская улица, д.27 к.2 в переменные
dom27_2_lat, dom27_2_lng= 55.670261, 37.451722
# сохраняем координаты жилого дома по адресу: Никулинская улица, д.27 к.3 в переменные
dom27_3_lat, dom27_3_lng = 55.669916, 37.450215
# сохраняем координаты ТЦ у метро Озёрная (3-й выход) в переменные
tc_lat, tc_lng = 55.671279, 37.449700

# создаём карту с центром в точке расположения ТРЦ Мичуринский и начальным зумом 16
m = folium.Map(location=[mishorinski_lat, mishorinski_lng], zoom_start=16)

# создаём маркер в точке расположения ТЦ Мичуринский и сразу добавляем на карту
folium.Marker([mishorinski_lat, mishorinski_lng]).add_to(m)
# создаём маркер в точке расположения дома по адресу: Никулинская улица, д.27 к.1 и сразу добавляем на карту
folium.Marker([dom27_1_lat, dom27_1_lng]).add_to(m)
# создаём маркер в точке расположения дома по адресу: Никулинская улица, д.27 к.2 и сразу добавляем на карту
folium.Marker([dom27_2_lat, dom27_2_lng]).add_to(m)
# создаём маркер в точке расположения дома по адресу: Никулинская улица, д.27 к.2 и сразу добавляем на карту
folium.Marker([dom27_3_lat, dom27_3_lng]).add_to(m)

# создаём маркер в точке расположения Малого театра и сразу добавляем на карту
folium.Marker([tc_lat, tc_lng]).add_to(m)

# выводим карту
m

# %% [markdown]
# Ссылка на просмотр презентации в pdf формате: https://disk.yandex.ru/i/hssMGZ5ISLhipA

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера по презентации:</b>
#
# Спасибо, что приложил ссылку на презентацию 😊
#
# У тебя получилась хорошая и понятная работа:
#
# - Очень здорово, что в целом придерживаешься правилу "один слайд - одна мысль" 👍
# - Молодец, что не перегружаешь презентацию текстом, если демонстрировать слайды, зрителям будет легче ориентироваться в информации

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера по презентации:</b>
#
# Несколько общих рекомендаций:
# - Подписать кто делал работу
# - Кратко указать цели исследования
# - Добавить нумерацию страниц
#
# </div>

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-info">
#
# ✅ **Материалы и рекомендации**:
#
# 1. Могу порекомендовать книгу **"Графики, которые убеждают всех" (автор Александр Богачев)**, там много полезного про визуализацию.
# 2. Шпаргалка по plotly. Набор опций с подробным описанием и примерами. https://habr.com/ru/post/502958/
# 3. Сайт, подробно представлюящий практически все типы визуализаций: https://datavizproject.com/
# 4. Построение холопретов: https://plotly.com/python/choropleth-maps/

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Заключительный комментарий ревьюера:</b>
#
# Василий, спасибо за проделанную работу!
#
# У тебя хороший проект, есть аккуратная структура, выводы по каждому этапу. И в целом все задания исследованы детально.
#
# Хочется отметить визуализации, ты молодец, что изучил и применил разные инструменты интерактивных графиков  🔥
#
#
# ***
#
# Есть несколько моментов на доработку:
# - **Этап Анализ данных:**
#     - доделать\скорректировать несколько заданий и графиков в соответствии с красными комментариями
# - **Этап Детализация:**
#     - доделать\скорректировать несколько заданий и графиков в соответствии с красными комментариями
#
# В остальном - все супер!
#
# ***
#
# Возвращаю тебе проект для внесения правок и вопросов)
#
# Успехов!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Заключительный комментарий ревьюера №2:</b>
#
# Василий, ты молодец, что доработал проект!
#
# Почти все супер 🔥
#
# Осталось только два вопроса на доработку (на этапе Анализа данных)
# -  **Рассмотрите и изобразите соотношение сетевых и несетевых заведений в датасете. Каких заведений больше?**
# - **Найдите улицы, на которых находится только один объект общепита. Что можно сказать об этих заведениях?**
#
# ***
#
# Возвращаю тебе проект для внесения правок и вопросов)
#
# Успехов!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Заключительный комментарий ревьюера №3:</b>
#
# Василий, ты молодец, что внес правки!
#
# Принимаю твой проект и желаю удачи в учебе  😊
#
# PS - рекомендую посмотреть вопрос **Рассмотрите и изобразите соотношение сетевых и несетевых заведений в датасете. Каких заведений больше?**, там я добавила комментрий и пример кода.
#
#
# </div>
